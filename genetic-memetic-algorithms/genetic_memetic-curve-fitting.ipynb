# %% [markdown]
# import needed libraries

# %%
import random
import math
import numpy as np

# %% [markdown]
# This class is for test case objects that saves different values of each object

# %%
class Data:

    # initialize needed values
    def __init__(self, data_address):
        self.address    = data_address      # address of test file
        self.degree     = 0                 # degree of polynomial
        self.low        = 0                 # lower bound of coefs
        self.high       = 0                 # upper bound of coefs
        self.num_points = 0                 # number of points in test case
        self.points     = []                # points of curve

    # read test case
    def load_data(self):
        with open (self.address, 'r') as f:
            self.degree         = int(f.readline())
            self.low, self.high = map(float, f.readline().split(" "))
            self.num_points     = int(f.readline())
            self.points         = [tuple(map(float, f.readline().split(" "))) for _ in range(self.num_points)]  # append the point to list of points

# %% [markdown]
# a class for gene objects, with different methods and values of a gene

# %%
class Gene:

    # initialize parameters
    def __init__(self, degree, points, low, high):
        self.gene    = []
        self.degree  = degree
        self.points  = points
        self.low     = low
        self.high    = high
        self.fitness = math.inf


    # create random gene for first population
    def initial_gene(self):
        self.gene = [random.uniform(self.low, self.high) for _ in range(self.degree)]

    # calculate fitness of the gene
    def fitness_function(self):
        y_pred       = [np.polyval(self.gene, point[0]) for point in self.points]  # predicted value for each point
        residuals    = [(y_pred[i] - self.points[i][1])**2 for i in range(len(self.points))]  # SSE for each point
        weight       = 1.0 / np.std(y_pred)
        weighted_rss = np.sqrt(weight * np.sum(residuals))   # calculate weighted RSS

        self.fitness = np.sqrt(weighted_rss)
        return self.fitness

    # mutate gene
    def mutation(self):

        i = random.randint(0, (self.degree-1)//2)
        j = random.randint((self.degree-1)//2, self.degree-1)
        k = random.randint((self.degree-1)//2, self.degree-1)

        # randomly change 3 coefs in gene
        self.gene[i] = np.round(random.uniform(-10000, 10000), 6)
        self.gene[j] = np.round(random.uniform(-10000, 10000), 6)
        self.gene[k] = np.round(random.uniform(-10000, 10000), 6)

        self.fitness = self.fitness_function()


    # define a local search to search for neighbors of a gene that is better than itself
    def local_search(self):

        neighbors = []
        for i in range(self.degree):   # find as many neighbors as degree of polynimal and change one index at a time
            genei = Gene(self.degree, self.points, self.low, self.high)
            rnd = np.round(random.uniform(-10000, 10000), 6)
            genei.gene = self.gene
            genei.gene[i] = rnd
            genei.fitness = genei.fitness_function()
            neighbors.append((genei.fitness, genei))

        # sort neighbors and select the best one or the child itself
        neighbors = sorted(neighbors, key=lambda x: x[0])
        if neighbors[0][0] < self.fitness:
            return neighbors[0][1]
        else:
            return self

# %% [markdown]
# a class for population of genes

# %%
class Population:

    # initialize population's parameters
    def __init__(self, data, pop_size=100):
        self.population_size             = pop_size
        self.population                  = []
        self.points                  = data.points
        self.low, self.high, self.degree = data.low, data.high, data.degree

    # generate first population randomly
    def initialize_population(self):
        for _ in range(self.population_size):
            genei = Gene(self.degree, self.points, self.low, self.high)
            genei.initial_gene()
            self.population.append(genei)


    # selest parents from population for crossover using tournament selection
    def parent_selection(self, N=3):
        # choose random N candidates to attend tournament
        father_candidates = [random.choice(self.population) for _ in range(N)]
        mother_candidates = [random.choice(self.population) for _ in range(N)]

        # choose the best one of N candidates to be a parent
        father_vals = [(father.fitness, father) for father in father_candidates]
        mother_vals = [(mother.fitness, mother) for mother in mother_candidates]

        # sort candidates
        sorted_fathers = sorted(father_vals, key=lambda x: x[0])
        sorted_mothers = sorted(mother_vals, key=lambda x: x[0])

        # select parents with min fitness
        best_father = sorted_fathers[0][1]
        best_mother = sorted_mothers[0][1]

        return best_father, best_mother

    # selest parents from population for crossover using rank-based selection
    def parent_selection_rank_based(self):
        # sort population based on fitness
        fitness_values = [gene.fitness for gene in self.population]
        ranked_indices = np.argsort(fitness_values)
        ranked_population = [self.population[i] for i in ranked_indices]

        # rank calculation for selection
        selection_p = np.arange(1, self.population_size + 1) / np.sum(np.arange(1, self.population_size + 1))

        # select parents based on rank and selection probabilities
        selected_parents = np.random.choice(ranked_population, size=2, replace=False, p=selection_p)

        return selected_parents[0], selected_parents[1]


    # crossover function (order)
    def crossover(self, father, mother):

        child1l, child2l = [], []
        child1, child2   = Gene(self.degree, self.points, self.low, self.high), Gene(self.degree, self.points, self.low, self.high)

        random_point = random.randint(0, (self.degree-1)//2)    # select a random point and cut 1 of parents for each child from there

        # put first part of 1 parent to each child
        child1l = [father.gene[i] for i in range(random_point)]
        child2l = [mother.gene[i] for i in range(random_point)]

        # put the rest of other parent
        for i in range(random_point, self.degree):
            child1l.append(mother.gene[i])
            child2l.append(father.gene[i])

        # initialize childs gene object
        child1.gene    = child1l
        child2.gene    = child2l
        child1.fitness = child1.fitness_function()
        child2.fitness = child2.fitness_function()

        # select the best generated child
        if child1.fitness < child2.fitness:
            return child1
        else:
            return child2

    # blend crossover
    def blx_alpha_crossover(self, father, mother, alpha=0.5):
        child = []
        for i in range(self.degree):
            min_val = min(father.gene[i], mother.gene[i])
            max_val = max(father.gene[i], mother.gene[i])

            parameter_range = max_val - min_val
            lower_bound     = min_val - alpha * parameter_range
            upper_bound     = max_val + alpha * parameter_range

            # check domain
            if lower_bound < self.low:
                lower_bound = self.low
            if upper_bound > self.high:
                upper_bound = self.high

            # generate a random value within the range
            child_val = np.random.uniform(lower_bound, upper_bound)
            child.append(child_val)

        # initialize child object
        child1 = Gene(self.degree, self.points, self.low, self.high)
        child1.gene = child
        child1.fitness = child1.fitness_function()
        return child1

    # average crossover function
    def avg_crossover(self, father, mother):

        child1l = []
        child1 = Gene(self.degree, self.points, self.low, self.high)

        # put first part of 1 parent to each child
        child1l = []

        # put the rest of other parent
        for i in range(self.degree):
            child1l.append((father.gene[i] + mother.gene[i]) / 2)

        # initialize childs gene object
        child1.gene = child1l
        child1.fitness = child1.fitness_function()

        return child1


    # random bit crossover function
    def rnd_crossover(self, father, mother):

        child1l = []
        child1 = Gene(self.degree, self.points, self.low, self.high)

        # specify the prob of selecting each parent's gene based on their fitness
        if father.fitness > mother.fitness:
            p_select = 0.3
        else:
            p_select = 0.7

        # put mother or father's gene in child gene with prob p_select
        for i in range(self.degree):
            e_select = random.random()
            if e_select > p_select:
                child1l[i] = father.gene[i]
            else:
                child1l[i] = mother.gene[i]


        # initialize childs gene object
        child1.gene = child1l
        child1.fitness = child1.fitness_function()

        return child1

# %% [markdown]
# ### Genetic (curve fitting)

# %%
def genetic_algorithm_main(test_address, generation_num, p_cross, p_mutate, p_replace, pop_size, stop_iter, expected_val, tornoment_N=3):
    # save best seen result
    best_cost = math.inf
    best_result = []

    # load test case
    testcase = Data(test_address)
    testcase.load_data()

    # step 1: create first population
    population = Population(testcase, pop_size=pop_size)
    population.initialize_population()

    iteration_without_change, g_num = 0, 0
    # iteration of running algorithm (number of generations)
    while True:
        g_num += 1 # iteration number
        children_population = Population(testcase, pop_size=pop_size)
        counter = 0
        # create as many children as parents population
        while counter < pop_size:

            # step 2: parent selection for crossover
            father1, mother1 = population.parent_selection_rank_based()
            father2, mother2 = population.parent_selection_rank_based()

            # step 3: crossover 2 selected parents with p_cross
            e_cross = random.random()
            if e_cross < p_cross:
                child1 = population.blx_alpha_crossover(father1, mother1, alpha=0.6)
                child2 = population.blx_alpha_crossover(father2, mother2, alpha=0.65)
                counter += 2

                # step 4: mutate children with p_mutate
                e_mutate1 = random.random()
                if e_mutate1 < p_mutate:
                    child1.mutation()
                e_mutate2 = random.random()
                if e_mutate2 < p_mutate:
                    child2.mutation()

                # add generated children to children population
                children_population.population.append(child1)
                children_population.population.append(child2)

        # step 5: population replacement
        parent_values = []
        child_values  = []
        for i in range(pop_size):             # save all values of parents and children in 2 value lists
            x = population.population[i].fitness
            y = children_population.population[i].fitness
            parent_values.append(x)
            child_values.append(y)

        num_replace = p_replace * pop_size    # find the number of parents that should be replaced with children in population

        # replace num_replace worst parent with best children
        for i in range(int(num_replace)):        # replace as the size of replacements in population
            max_parent_ind = parent_values.index(max(parent_values))    # find the worst parent
            min_child_ind  = child_values.index(min(child_values))      # find best children

            population.population.pop(max_parent_ind)      # remove worst parent from population
            population.population.append(children_population.population[min_child_ind])  # add best children to population

            children_population.population.pop(min_child_ind)  # remove best children from population of children
            parent_values.pop(max_parent_ind)   # remove worst parent value from parents values
            child_values.pop(min_child_ind)  # remove best children value from children values

        # step 6: population fitness check, find the best result in population
        flag = False
        for i in range(pop_size):
            if population.population[i].fitness < best_cost:
                best_cost   = population.population[i].fitness
                best_result = population.population[i].gene.copy()
                iteration_without_change = 0
                flag = True
        if not flag:
            iteration_without_change += 1

        print(f"Iteration {g_num}, best_cost so far: {np.round(best_cost, 3)}")

        # step 7: check stop condition
        if best_cost < expected_val or iteration_without_change > stop_iter:
            break


    return best_result, testcase

# %% [markdown]
# Test 1

# %%
best_result, test = genetic_algorithm_main(test_address="CurveFitting-Tests/CurveFitting_test1.txt", generation_num=500, p_cross=0.65, p_mutate=0.5, p_replace=0.1, pop_size=200, stop_iter=100, expected_val=100)
# Out:
# Iteration 1, best_cost so far: 57693.328
# Iteration 2, best_cost so far: 19596.695
# Iteration 3, best_cost so far: 19596.695
# Iteration 4, best_cost so far: 19596.695
# Iteration 5, best_cost so far: 9519.209
# Iteration 6, best_cost so far: 9519.209
# Iteration 7, best_cost so far: 9519.209
# Iteration 8, best_cost so far: 9519.209
# Iteration 9, best_cost so far: 9519.209
# Iteration 10, best_cost so far: 9519.209
# Iteration 11, best_cost so far: 9519.209
# Iteration 12, best_cost so far: 9519.209
# Iteration 13, best_cost so far: 8307.142
# Iteration 14, best_cost so far: 8307.142
# Iteration 15, best_cost so far: 8307.142
# Iteration 16, best_cost so far: 418.916
# Iteration 17, best_cost so far: 418.916
# Iteration 18, best_cost so far: 418.916
# Iteration 19, best_cost so far: 418.916
# Iteration 20, best_cost so far: 418.916
# Iteration 21, best_cost so far: 418.916
# Iteration 22, best_cost so far: 418.916
# Iteration 23, best_cost so far: 418.916
# Iteration 24, best_cost so far: 418.916
# Iteration 25, best_cost so far: 418.916
# Iteration 26, best_cost so far: 418.916
# Iteration 27, best_cost so far: 418.916
# Iteration 28, best_cost so far: 418.916
# Iteration 29, best_cost so far: 418.916
# Iteration 30, best_cost so far: 418.916
# Iteration 31, best_cost so far: 418.916
# Iteration 32, best_cost so far: 418.916
# Iteration 33, best_cost so far: 418.916
# Iteration 34, best_cost so far: 418.916
# Iteration 35, best_cost so far: 418.916
# Iteration 36, best_cost so far: 418.916
# Iteration 37, best_cost so far: 418.916
# Iteration 38, best_cost so far: 418.916
# Iteration 39, best_cost so far: 418.916
# Iteration 40, best_cost so far: 418.916
# Iteration 41, best_cost so far: 418.916
# Iteration 42, best_cost so far: 392.574
# Iteration 43, best_cost so far: 342.842
# Iteration 44, best_cost so far: 342.842
# Iteration 45, best_cost so far: 342.842
# Iteration 46, best_cost so far: 326.863
# Iteration 47, best_cost so far: 326.863
# Iteration 48, best_cost so far: 326.863
# Iteration 49, best_cost so far: 326.863
# Iteration 50, best_cost so far: 326.863
# Iteration 51, best_cost so far: 326.863
# Iteration 52, best_cost so far: 287.284
# Iteration 53, best_cost so far: 287.284
# Iteration 54, best_cost so far: 287.284
# Iteration 55, best_cost so far: 287.284
# Iteration 56, best_cost so far: 287.284
# Iteration 57, best_cost so far: 287.284
# Iteration 58, best_cost so far: 287.284
# Iteration 59, best_cost so far: 287.284
# Iteration 60, best_cost so far: 263.758
# Iteration 61, best_cost so far: 263.758
# Iteration 62, best_cost so far: 263.758
# Iteration 63, best_cost so far: 263.758
# Iteration 64, best_cost so far: 263.758
# Iteration 65, best_cost so far: 263.758
# Iteration 66, best_cost so far: 263.758
# Iteration 67, best_cost so far: 263.758
# Iteration 68, best_cost so far: 263.758
# Iteration 69, best_cost so far: 263.758
# Iteration 70, best_cost so far: 263.758
# Iteration 71, best_cost so far: 263.758
# Iteration 72, best_cost so far: 263.758
# Iteration 73, best_cost so far: 263.758
# Iteration 74, best_cost so far: 263.758
# Iteration 75, best_cost so far: 263.758
# Iteration 76, best_cost so far: 263.758
# Iteration 77, best_cost so far: 263.758
# Iteration 78, best_cost so far: 263.758
# Iteration 79, best_cost so far: 263.758
# Iteration 80, best_cost so far: 263.758
# Iteration 81, best_cost so far: 263.758
# Iteration 82, best_cost so far: 263.758
# Iteration 83, best_cost so far: 263.758
# Iteration 84, best_cost so far: 263.758
# Iteration 85, best_cost so far: 263.758
# Iteration 86, best_cost so far: 263.758
# Iteration 87, best_cost so far: 263.758
# Iteration 88, best_cost so far: 263.758
# Iteration 89, best_cost so far: 263.758
# Iteration 90, best_cost so far: 263.758
# Iteration 91, best_cost so far: 263.758
# Iteration 92, best_cost so far: 263.758
# Iteration 93, best_cost so far: 263.758
# Iteration 94, best_cost so far: 263.758
# Iteration 95, best_cost so far: 263.758
# Iteration 96, best_cost so far: 263.758
# Iteration 97, best_cost so far: 263.758
# Iteration 98, best_cost so far: 263.758
# Iteration 99, best_cost so far: 263.758
# Iteration 100, best_cost so far: 263.758
# Iteration 101, best_cost so far: 263.758
# Iteration 102, best_cost so far: 263.758
# Iteration 103, best_cost so far: 263.758
# Iteration 104, best_cost so far: 263.758
# Iteration 105, best_cost so far: 263.758
# Iteration 106, best_cost so far: 263.758
# Iteration 107, best_cost so far: 263.758
# Iteration 108, best_cost so far: 261.416
# Iteration 109, best_cost so far: 261.416
# Iteration 110, best_cost so far: 261.416
# Iteration 111, best_cost so far: 261.416
# Iteration 112, best_cost so far: 261.416
# Iteration 113, best_cost so far: 261.416
# Iteration 114, best_cost so far: 261.416
# Iteration 115, best_cost so far: 261.416
# Iteration 116, best_cost so far: 261.416
# Iteration 117, best_cost so far: 261.416
# Iteration 118, best_cost so far: 261.416
# Iteration 119, best_cost so far: 261.416
# Iteration 120, best_cost so far: 261.416
# Iteration 121, best_cost so far: 261.416
# Iteration 122, best_cost so far: 261.416
# Iteration 123, best_cost so far: 261.416
# Iteration 124, best_cost so far: 261.416
# Iteration 125, best_cost so far: 261.416
# Iteration 126, best_cost so far: 261.416
# Iteration 127, best_cost so far: 261.416
# Iteration 128, best_cost so far: 261.416
# Iteration 129, best_cost so far: 261.416
# Iteration 130, best_cost so far: 261.416
# Iteration 131, best_cost so far: 261.416
# Iteration 132, best_cost so far: 261.416
# Iteration 133, best_cost so far: 261.416
# Iteration 134, best_cost so far: 261.416
# Iteration 135, best_cost so far: 261.416
# Iteration 136, best_cost so far: 261.416
# Iteration 137, best_cost so far: 261.416
# Iteration 138, best_cost so far: 261.416
# Iteration 139, best_cost so far: 261.416
# Iteration 140, best_cost so far: 261.416
# Iteration 141, best_cost so far: 261.416
# Iteration 142, best_cost so far: 261.416
# Iteration 143, best_cost so far: 261.416
# Iteration 144, best_cost so far: 261.284
# Iteration 145, best_cost so far: 261.284
# Iteration 146, best_cost so far: 261.284
# Iteration 147, best_cost so far: 261.284
# Iteration 148, best_cost so far: 261.284
# Iteration 149, best_cost so far: 261.284
# Iteration 150, best_cost so far: 261.284
# Iteration 151, best_cost so far: 261.284
# Iteration 152, best_cost so far: 261.284
# Iteration 153, best_cost so far: 261.284
# Iteration 154, best_cost so far: 261.284
# Iteration 155, best_cost so far: 261.284
# Iteration 156, best_cost so far: 261.284
# Iteration 157, best_cost so far: 261.284
# Iteration 158, best_cost so far: 261.284
# Iteration 159, best_cost so far: 261.284
# Iteration 160, best_cost so far: 261.284
# Iteration 161, best_cost so far: 261.284
# Iteration 162, best_cost so far: 261.284
# Iteration 163, best_cost so far: 261.284
# Iteration 164, best_cost so far: 261.284
# Iteration 165, best_cost so far: 261.284
# Iteration 166, best_cost so far: 261.284
# Iteration 167, best_cost so far: 261.284
# Iteration 168, best_cost so far: 261.284
# Iteration 169, best_cost so far: 261.284
# Iteration 170, best_cost so far: 261.284
# Iteration 171, best_cost so far: 261.284
# Iteration 172, best_cost so far: 261.284
# Iteration 173, best_cost so far: 261.284
# Iteration 174, best_cost so far: 261.284
# Iteration 175, best_cost so far: 261.284
# Iteration 176, best_cost so far: 261.284
# Iteration 177, best_cost so far: 261.284
# Iteration 178, best_cost so far: 261.284
# Iteration 179, best_cost so far: 261.284
# Iteration 180, best_cost so far: 261.284
# Iteration 181, best_cost so far: 259.131
# Iteration 182, best_cost so far: 259.131
# Iteration 183, best_cost so far: 259.131
# Iteration 184, best_cost so far: 259.131
# Iteration 185, best_cost so far: 259.131
# Iteration 186, best_cost so far: 259.131
# Iteration 187, best_cost so far: 259.131
# Iteration 188, best_cost so far: 259.131
# Iteration 189, best_cost so far: 259.131
# Iteration 190, best_cost so far: 259.131
# Iteration 191, best_cost so far: 259.131
# Iteration 192, best_cost so far: 259.131
# Iteration 193, best_cost so far: 259.131
# Iteration 194, best_cost so far: 259.131
# Iteration 195, best_cost so far: 259.131
# Iteration 196, best_cost so far: 259.131
# Iteration 197, best_cost so far: 259.131
# Iteration 198, best_cost so far: 259.131
# Iteration 199, best_cost so far: 259.131
# Iteration 200, best_cost so far: 259.131
# Iteration 201, best_cost so far: 259.131
# Iteration 202, best_cost so far: 259.131
# Iteration 203, best_cost so far: 259.131
# Iteration 204, best_cost so far: 259.131
# Iteration 205, best_cost so far: 259.131
# Iteration 206, best_cost so far: 259.131
# Iteration 207, best_cost so far: 259.131
# Iteration 208, best_cost so far: 259.131
# Iteration 209, best_cost so far: 259.131
# Iteration 210, best_cost so far: 259.131
# Iteration 211, best_cost so far: 259.131
# Iteration 212, best_cost so far: 259.131
# Iteration 213, best_cost so far: 259.131
# Iteration 214, best_cost so far: 259.131
# Iteration 215, best_cost so far: 259.131
# Iteration 216, best_cost so far: 259.131
# Iteration 217, best_cost so far: 259.131
# Iteration 218, best_cost so far: 259.131
# Iteration 219, best_cost so far: 259.131
# Iteration 220, best_cost so far: 259.131
# Iteration 221, best_cost so far: 259.131
# Iteration 222, best_cost so far: 259.131
# Iteration 223, best_cost so far: 259.131
# Iteration 224, best_cost so far: 259.131
# Iteration 225, best_cost so far: 259.131
# Iteration 226, best_cost so far: 259.131
# Iteration 227, best_cost so far: 259.131
# Iteration 228, best_cost so far: 259.131
# Iteration 229, best_cost so far: 259.131
# Iteration 230, best_cost so far: 259.131
# Iteration 231, best_cost so far: 259.131
# Iteration 232, best_cost so far: 259.131
# Iteration 233, best_cost so far: 259.131
# Iteration 234, best_cost so far: 259.131
# Iteration 235, best_cost so far: 259.131
# Iteration 236, best_cost so far: 259.131
# Iteration 237, best_cost so far: 259.131
# Iteration 238, best_cost so far: 259.131
# Iteration 239, best_cost so far: 259.131
# Iteration 240, best_cost so far: 259.131
# Iteration 241, best_cost so far: 259.131
# Iteration 242, best_cost so far: 259.131
# Iteration 243, best_cost so far: 259.131
# Iteration 244, best_cost so far: 259.131
# Iteration 245, best_cost so far: 259.131
# Iteration 246, best_cost so far: 259.131
# Iteration 247, best_cost so far: 259.131
# Iteration 248, best_cost so far: 259.131
# Iteration 249, best_cost so far: 259.131
# Iteration 250, best_cost so far: 259.131
# Iteration 251, best_cost so far: 259.131
# Iteration 252, best_cost so far: 259.131
# Iteration 253, best_cost so far: 259.131
# Iteration 254, best_cost so far: 259.131
# Iteration 255, best_cost so far: 259.131
# Iteration 256, best_cost so far: 259.131
# Iteration 257, best_cost so far: 259.131
# Iteration 258, best_cost so far: 259.131
# Iteration 259, best_cost so far: 259.131
# Iteration 260, best_cost so far: 259.131
# Iteration 261, best_cost so far: 259.131
# Iteration 262, best_cost so far: 259.131
# Iteration 263, best_cost so far: 259.131
# Iteration 264, best_cost so far: 259.131
# Iteration 265, best_cost so far: 259.131
# Iteration 266, best_cost so far: 259.131
# Iteration 267, best_cost so far: 259.131
# Iteration 268, best_cost so far: 259.131
# Iteration 269, best_cost so far: 259.131
# Iteration 270, best_cost so far: 259.131
# Iteration 271, best_cost so far: 259.131
# Iteration 272, best_cost so far: 259.131
# Iteration 273, best_cost so far: 259.131
# Iteration 274, best_cost so far: 259.131
# Iteration 275, best_cost so far: 259.131
# Iteration 276, best_cost so far: 259.131
# Iteration 277, best_cost so far: 259.131
# Iteration 278, best_cost so far: 259.131
# Iteration 279, best_cost so far: 259.131
# Iteration 280, best_cost so far: 259.131
# Iteration 281, best_cost so far: 259.131
# Iteration 282, best_cost so far: 259.131

# %% [markdown]
# Test 2

# %%
best_result, test = genetic_algorithm_main(test_address="CurveFitting-Tests/CurveFitting_test2.txt", generation_num=500, p_cross=0.65, p_mutate=0.5, p_replace=0.1, pop_size=200, stop_iter=100, expected_val=100)
# Out:
# Iteration 1, best_cost so far: 14540.922
# Iteration 2, best_cost so far: 11935.463
# Iteration 3, best_cost so far: 11935.463
# Iteration 4, best_cost so far: 11935.463
# Iteration 5, best_cost so far: 11935.463
# Iteration 6, best_cost so far: 1933.533
# Iteration 7, best_cost so far: 1933.533
# Iteration 8, best_cost so far: 1933.533
# Iteration 9, best_cost so far: 1933.533
# Iteration 10, best_cost so far: 1933.533
# Iteration 11, best_cost so far: 1933.533
# Iteration 12, best_cost so far: 1933.533
# Iteration 13, best_cost so far: 1933.533
# Iteration 14, best_cost so far: 1933.533
# Iteration 15, best_cost so far: 1933.533
# Iteration 16, best_cost so far: 1933.533
# Iteration 17, best_cost so far: 1853.855
# Iteration 18, best_cost so far: 1853.855
# Iteration 19, best_cost so far: 1853.855
# Iteration 20, best_cost so far: 1608.162
# Iteration 21, best_cost so far: 1455.716
# Iteration 22, best_cost so far: 1455.716
# Iteration 23, best_cost so far: 1455.716
# Iteration 24, best_cost so far: 1455.716
# Iteration 25, best_cost so far: 1455.716
# Iteration 26, best_cost so far: 1429.239
# Iteration 27, best_cost so far: 1429.239
# Iteration 28, best_cost so far: 978.994
# Iteration 29, best_cost so far: 978.994
# Iteration 30, best_cost so far: 978.994
# Iteration 31, best_cost so far: 978.994
# Iteration 32, best_cost so far: 978.994
# Iteration 33, best_cost so far: 978.994
# Iteration 34, best_cost so far: 978.994
# Iteration 35, best_cost so far: 978.994
# Iteration 36, best_cost so far: 978.994
# Iteration 37, best_cost so far: 978.994
# Iteration 38, best_cost so far: 978.994
# Iteration 39, best_cost so far: 978.994
# Iteration 40, best_cost so far: 978.994
# Iteration 41, best_cost so far: 978.994
# Iteration 42, best_cost so far: 978.994
# Iteration 43, best_cost so far: 978.994
# Iteration 44, best_cost so far: 978.994
# Iteration 45, best_cost so far: 978.994
# Iteration 46, best_cost so far: 978.994
# Iteration 47, best_cost so far: 978.994
# Iteration 48, best_cost so far: 978.994
# Iteration 49, best_cost so far: 978.994
# Iteration 50, best_cost so far: 978.994
# Iteration 51, best_cost so far: 978.994
# Iteration 52, best_cost so far: 778.52
# Iteration 53, best_cost so far: 778.52
# Iteration 54, best_cost so far: 778.52
# Iteration 55, best_cost so far: 778.52
# Iteration 56, best_cost so far: 778.52
# Iteration 57, best_cost so far: 778.52
# Iteration 58, best_cost so far: 778.52
# Iteration 59, best_cost so far: 778.52
# Iteration 60, best_cost so far: 778.52
# Iteration 61, best_cost so far: 778.52
# Iteration 62, best_cost so far: 778.52
# Iteration 63, best_cost so far: 778.52
# Iteration 64, best_cost so far: 778.52
# Iteration 65, best_cost so far: 778.52
# Iteration 66, best_cost so far: 778.52
# Iteration 67, best_cost so far: 778.52
# Iteration 68, best_cost so far: 778.52
# Iteration 69, best_cost so far: 778.52
# Iteration 70, best_cost so far: 778.52
# Iteration 71, best_cost so far: 778.52
# Iteration 72, best_cost so far: 778.52
# Iteration 73, best_cost so far: 778.52
# Iteration 74, best_cost so far: 778.52
# Iteration 75, best_cost so far: 778.52
# Iteration 76, best_cost so far: 778.52
# Iteration 77, best_cost so far: 778.52
# Iteration 78, best_cost so far: 778.52
# Iteration 79, best_cost so far: 778.52
# Iteration 80, best_cost so far: 778.52
# Iteration 81, best_cost so far: 778.52
# Iteration 82, best_cost so far: 778.52
# Iteration 83, best_cost so far: 778.52
# Iteration 84, best_cost so far: 778.52
# Iteration 85, best_cost so far: 778.52
# Iteration 86, best_cost so far: 778.52
# Iteration 87, best_cost so far: 778.52
# Iteration 88, best_cost so far: 778.52
# Iteration 89, best_cost so far: 778.52
# Iteration 90, best_cost so far: 778.52
# Iteration 91, best_cost so far: 778.52
# Iteration 92, best_cost so far: 778.52
# Iteration 93, best_cost so far: 778.52
# Iteration 94, best_cost so far: 778.52
# Iteration 95, best_cost so far: 778.52
# Iteration 96, best_cost so far: 778.52
# Iteration 97, best_cost so far: 778.52
# Iteration 98, best_cost so far: 778.52
# Iteration 99, best_cost so far: 778.52
# Iteration 100, best_cost so far: 778.52
# Iteration 101, best_cost so far: 778.52
# Iteration 102, best_cost so far: 778.52
# Iteration 103, best_cost so far: 778.52
# Iteration 104, best_cost so far: 778.52
# Iteration 105, best_cost so far: 778.52
# Iteration 106, best_cost so far: 758.938
# Iteration 107, best_cost so far: 758.938
# Iteration 108, best_cost so far: 758.938
# Iteration 109, best_cost so far: 758.938
# Iteration 110, best_cost so far: 758.938
# Iteration 111, best_cost so far: 758.938
# Iteration 112, best_cost so far: 758.938
# Iteration 113, best_cost so far: 758.938
# Iteration 114, best_cost so far: 758.938
# Iteration 115, best_cost so far: 758.938
# Iteration 116, best_cost so far: 758.938
# Iteration 117, best_cost so far: 758.938
# Iteration 118, best_cost so far: 758.938
# Iteration 119, best_cost so far: 758.938
# Iteration 120, best_cost so far: 758.938
# Iteration 121, best_cost so far: 758.938
# Iteration 122, best_cost so far: 758.938
# Iteration 123, best_cost so far: 758.938
# Iteration 124, best_cost so far: 758.938
# Iteration 125, best_cost so far: 758.938
# Iteration 126, best_cost so far: 758.938
# Iteration 127, best_cost so far: 758.938
# Iteration 128, best_cost so far: 758.938
# Iteration 129, best_cost so far: 758.938
# Iteration 130, best_cost so far: 758.938
# Iteration 131, best_cost so far: 758.938
# Iteration 132, best_cost so far: 758.938
# Iteration 133, best_cost so far: 758.938
# Iteration 134, best_cost so far: 634.947
# Iteration 135, best_cost so far: 634.947
# Iteration 136, best_cost so far: 634.947
# Iteration 137, best_cost so far: 634.947
# Iteration 138, best_cost so far: 634.947
# Iteration 139, best_cost so far: 634.947
# Iteration 140, best_cost so far: 634.947
# Iteration 141, best_cost so far: 634.947
# Iteration 142, best_cost so far: 634.947
# Iteration 143, best_cost so far: 634.947
# Iteration 144, best_cost so far: 634.947
# Iteration 145, best_cost so far: 634.947
# Iteration 146, best_cost so far: 634.947
# Iteration 147, best_cost so far: 634.947
# Iteration 148, best_cost so far: 634.947
# Iteration 149, best_cost so far: 634.947
# Iteration 150, best_cost so far: 634.947
# Iteration 151, best_cost so far: 634.947
# Iteration 152, best_cost so far: 634.947
# Iteration 153, best_cost so far: 634.947
# Iteration 154, best_cost so far: 634.947
# Iteration 155, best_cost so far: 634.947
# Iteration 156, best_cost so far: 634.947
# Iteration 157, best_cost so far: 634.947
# Iteration 158, best_cost so far: 457.199
# Iteration 159, best_cost so far: 457.199
# Iteration 160, best_cost so far: 457.199
# Iteration 161, best_cost so far: 457.199
# Iteration 162, best_cost so far: 457.199
# Iteration 163, best_cost so far: 457.199
# Iteration 164, best_cost so far: 457.199
# Iteration 165, best_cost so far: 457.199
# Iteration 166, best_cost so far: 457.199
# Iteration 167, best_cost so far: 457.199
# Iteration 168, best_cost so far: 457.199
# Iteration 169, best_cost so far: 457.199
# Iteration 170, best_cost so far: 457.199
# Iteration 171, best_cost so far: 457.199
# Iteration 172, best_cost so far: 457.199
# Iteration 173, best_cost so far: 457.199
# Iteration 174, best_cost so far: 457.199
# Iteration 175, best_cost so far: 457.199
# Iteration 176, best_cost so far: 457.199
# Iteration 177, best_cost so far: 457.199
# Iteration 178, best_cost so far: 457.199
# Iteration 179, best_cost so far: 457.199
# Iteration 180, best_cost so far: 457.199
# Iteration 181, best_cost so far: 457.199
# Iteration 182, best_cost so far: 457.199
# Iteration 183, best_cost so far: 457.199
# Iteration 184, best_cost so far: 457.199
# Iteration 185, best_cost so far: 457.199
# Iteration 186, best_cost so far: 457.199
# Iteration 187, best_cost so far: 457.199
# Iteration 188, best_cost so far: 457.199
# Iteration 189, best_cost so far: 457.199
# Iteration 190, best_cost so far: 457.199
# Iteration 191, best_cost so far: 457.199
# Iteration 192, best_cost so far: 457.199
# Iteration 193, best_cost so far: 457.199
# Iteration 194, best_cost so far: 457.199
# Iteration 195, best_cost so far: 457.199
# Iteration 196, best_cost so far: 457.199
# Iteration 197, best_cost so far: 457.199
# Iteration 198, best_cost so far: 457.199
# Iteration 199, best_cost so far: 457.199
# Iteration 200, best_cost so far: 457.199
# Iteration 201, best_cost so far: 457.199
# Iteration 202, best_cost so far: 457.199
# Iteration 203, best_cost so far: 457.199
# Iteration 204, best_cost so far: 457.199
# Iteration 205, best_cost so far: 457.199
# Iteration 206, best_cost so far: 457.199
# Iteration 207, best_cost so far: 457.199
# Iteration 208, best_cost so far: 457.199
# Iteration 209, best_cost so far: 457.199
# Iteration 210, best_cost so far: 457.199
# Iteration 211, best_cost so far: 457.199
# Iteration 212, best_cost so far: 457.199
# Iteration 213, best_cost so far: 457.199
# Iteration 214, best_cost so far: 457.199
# Iteration 215, best_cost so far: 457.199
# Iteration 216, best_cost so far: 457.199
# Iteration 217, best_cost so far: 457.199
# Iteration 218, best_cost so far: 457.199
# Iteration 219, best_cost so far: 457.199
# Iteration 220, best_cost so far: 457.199
# Iteration 221, best_cost so far: 457.199
# Iteration 222, best_cost so far: 457.199
# Iteration 223, best_cost so far: 457.199
# Iteration 224, best_cost so far: 457.199
# Iteration 225, best_cost so far: 457.199
# Iteration 226, best_cost so far: 457.199
# Iteration 227, best_cost so far: 457.199
# Iteration 228, best_cost so far: 457.199
# Iteration 229, best_cost so far: 457.199
# Iteration 230, best_cost so far: 457.199
# Iteration 231, best_cost so far: 457.199
# Iteration 232, best_cost so far: 457.199
# Iteration 233, best_cost so far: 457.199
# Iteration 234, best_cost so far: 457.199
# Iteration 235, best_cost so far: 457.199
# Iteration 236, best_cost so far: 457.199
# Iteration 237, best_cost so far: 457.199
# Iteration 238, best_cost so far: 457.199
# Iteration 239, best_cost so far: 457.199
# Iteration 240, best_cost so far: 457.199
# Iteration 241, best_cost so far: 457.199
# Iteration 242, best_cost so far: 457.199
# Iteration 243, best_cost so far: 457.199
# Iteration 244, best_cost so far: 457.199
# Iteration 245, best_cost so far: 457.199
# Iteration 246, best_cost so far: 457.199
# Iteration 247, best_cost so far: 457.199
# Iteration 248, best_cost so far: 457.199
# Iteration 249, best_cost so far: 457.199
# Iteration 250, best_cost so far: 457.199
# Iteration 251, best_cost so far: 457.199
# Iteration 252, best_cost so far: 457.199
# Iteration 253, best_cost so far: 457.199
# Iteration 254, best_cost so far: 457.199
# Iteration 255, best_cost so far: 457.199
# Iteration 256, best_cost so far: 457.199
# Iteration 257, best_cost so far: 457.199
# Iteration 258, best_cost so far: 457.199
# Iteration 259, best_cost so far: 457.199

# %% [markdown]
# Test 3

# %%
best_result, test = genetic_algorithm_main(test_address="CurveFitting-Tests/CurveFitting_test3.txt", generation_num=500, p_cross=0.65, p_mutate=0.5, p_replace=0.1, pop_size=100, stop_iter=100, expected_val=100)
# Out:
# Iteration 1, best_cost so far: 64676.956
# Iteration 2, best_cost so far: 21426.365
# Iteration 3, best_cost so far: 21426.365
# Iteration 4, best_cost so far: 21426.365
# Iteration 5, best_cost so far: 21426.365
# Iteration 6, best_cost so far: 21426.365
# Iteration 7, best_cost so far: 21426.365
# Iteration 8, best_cost so far: 21426.365
# Iteration 9, best_cost so far: 10580.094
# Iteration 10, best_cost so far: 10580.094
# Iteration 11, best_cost so far: 10580.094
# Iteration 12, best_cost so far: 10580.094
# Iteration 13, best_cost so far: 10580.094
# Iteration 14, best_cost so far: 10580.094
# Iteration 15, best_cost so far: 10580.094
# Iteration 16, best_cost so far: 10580.094
# Iteration 17, best_cost so far: 10580.094
# Iteration 18, best_cost so far: 10580.094
# Iteration 19, best_cost so far: 10580.094
# Iteration 20, best_cost so far: 10580.094
# Iteration 21, best_cost so far: 10580.094
# Iteration 22, best_cost so far: 10580.094
# Iteration 23, best_cost so far: 10580.094
# Iteration 24, best_cost so far: 10580.094
# Iteration 25, best_cost so far: 10580.094
# Iteration 26, best_cost so far: 10580.094
# Iteration 27, best_cost so far: 10580.094
# Iteration 28, best_cost so far: 10580.094
# Iteration 29, best_cost so far: 10580.094
# Iteration 30, best_cost so far: 10580.094
# Iteration 31, best_cost so far: 10580.094
# Iteration 32, best_cost so far: 10580.094
# Iteration 33, best_cost so far: 10580.094
# Iteration 34, best_cost so far: 9184.2
# Iteration 35, best_cost so far: 9184.2
# Iteration 36, best_cost so far: 9184.2
# Iteration 37, best_cost so far: 9184.2
# Iteration 38, best_cost so far: 7977.945
# Iteration 39, best_cost so far: 7977.945
# Iteration 40, best_cost so far: 7977.945
# Iteration 41, best_cost so far: 7977.945
# Iteration 42, best_cost so far: 7977.945
# Iteration 43, best_cost so far: 7977.945
# Iteration 44, best_cost so far: 7376.596
# Iteration 45, best_cost so far: 7376.596
# Iteration 46, best_cost so far: 7376.596
# Iteration 47, best_cost so far: 7376.596
# Iteration 48, best_cost so far: 7376.596
# Iteration 49, best_cost so far: 7376.596
# Iteration 50, best_cost so far: 6591.894
# Iteration 51, best_cost so far: 6591.894
# Iteration 52, best_cost so far: 6591.894
# Iteration 53, best_cost so far: 6591.894
# Iteration 54, best_cost so far: 6591.894
# Iteration 55, best_cost so far: 6591.894
# Iteration 56, best_cost so far: 6591.894
# Iteration 57, best_cost so far: 6591.894
# Iteration 58, best_cost so far: 6591.894
# Iteration 59, best_cost so far: 6591.894
# Iteration 60, best_cost so far: 6591.894
# Iteration 61, best_cost so far: 6591.894
# Iteration 62, best_cost so far: 6591.894
# Iteration 63, best_cost so far: 6591.894
# Iteration 64, best_cost so far: 6174.153
# Iteration 65, best_cost so far: 6174.153
# Iteration 66, best_cost so far: 6174.153
# Iteration 67, best_cost so far: 6174.153
# Iteration 68, best_cost so far: 6174.153
# Iteration 69, best_cost so far: 6174.153
# Iteration 70, best_cost so far: 6174.153
# Iteration 71, best_cost so far: 6174.153
# Iteration 72, best_cost so far: 6174.153
# Iteration 73, best_cost so far: 6174.153
# Iteration 74, best_cost so far: 6174.153
# Iteration 75, best_cost so far: 6174.153
# Iteration 76, best_cost so far: 6174.153
# Iteration 77, best_cost so far: 6174.153
# Iteration 78, best_cost so far: 6174.153
# Iteration 79, best_cost so far: 6174.153
# Iteration 80, best_cost so far: 6174.153
# Iteration 81, best_cost so far: 6174.153
# Iteration 82, best_cost so far: 6174.153
# Iteration 83, best_cost so far: 6174.153
# Iteration 84, best_cost so far: 6174.153
# Iteration 85, best_cost so far: 6174.153
# Iteration 86, best_cost so far: 6174.153
# Iteration 87, best_cost so far: 6174.153
# Iteration 88, best_cost so far: 6174.153
# Iteration 89, best_cost so far: 6174.153
# Iteration 90, best_cost so far: 6174.153
# Iteration 91, best_cost so far: 6174.153
# Iteration 92, best_cost so far: 6174.153
# Iteration 93, best_cost so far: 6174.153
# Iteration 94, best_cost so far: 6174.153
# Iteration 95, best_cost so far: 6174.153
# Iteration 96, best_cost so far: 6174.153
# Iteration 97, best_cost so far: 6174.153
# Iteration 98, best_cost so far: 6174.153
# Iteration 99, best_cost so far: 6174.153
# Iteration 100, best_cost so far: 6174.153
# Iteration 101, best_cost so far: 6174.153
# Iteration 102, best_cost so far: 6174.153
# Iteration 103, best_cost so far: 6174.153
# Iteration 104, best_cost so far: 6174.153
# Iteration 105, best_cost so far: 6174.153
# Iteration 106, best_cost so far: 6174.153
# Iteration 107, best_cost so far: 6174.153
# Iteration 108, best_cost so far: 6174.153
# Iteration 109, best_cost so far: 6174.153
# Iteration 110, best_cost so far: 6174.153
# Iteration 111, best_cost so far: 6174.153
# Iteration 112, best_cost so far: 6174.153
# Iteration 113, best_cost so far: 6174.153
# Iteration 114, best_cost so far: 6174.153
# Iteration 115, best_cost so far: 6174.153
# Iteration 116, best_cost so far: 6174.153
# Iteration 117, best_cost so far: 6174.153
# Iteration 118, best_cost so far: 6174.153
# Iteration 119, best_cost so far: 6174.153
# Iteration 120, best_cost so far: 6174.153
# Iteration 121, best_cost so far: 6174.153
# Iteration 122, best_cost so far: 6174.153
# Iteration 123, best_cost so far: 6174.153
# Iteration 124, best_cost so far: 6174.153
# Iteration 125, best_cost so far: 6174.153
# Iteration 126, best_cost so far: 6174.153
# Iteration 127, best_cost so far: 6174.153
# Iteration 128, best_cost so far: 6174.153
# Iteration 129, best_cost so far: 6174.153
# Iteration 130, best_cost so far: 6174.153
# Iteration 131, best_cost so far: 6174.153
# Iteration 132, best_cost so far: 6174.153
# Iteration 133, best_cost so far: 6174.153
# Iteration 134, best_cost so far: 6174.153
# Iteration 135, best_cost so far: 6174.153
# Iteration 136, best_cost so far: 6174.153
# Iteration 137, best_cost so far: 6174.153
# Iteration 138, best_cost so far: 6174.153
# Iteration 139, best_cost so far: 6174.153
# Iteration 140, best_cost so far: 6174.153
# Iteration 141, best_cost so far: 6174.153
# Iteration 142, best_cost so far: 6174.153
# Iteration 143, best_cost so far: 6174.153
# Iteration 144, best_cost so far: 6174.153
# Iteration 145, best_cost so far: 6174.153
# Iteration 146, best_cost so far: 6174.153
# Iteration 147, best_cost so far: 6174.153
# Iteration 148, best_cost so far: 6174.153
# Iteration 149, best_cost so far: 6174.153
# Iteration 150, best_cost so far: 6174.153
# Iteration 151, best_cost so far: 6174.153
# Iteration 152, best_cost so far: 6174.153
# Iteration 153, best_cost so far: 6174.153
# Iteration 154, best_cost so far: 6174.153
# Iteration 155, best_cost so far: 6174.153
# Iteration 156, best_cost so far: 6174.153
# Iteration 157, best_cost so far: 6174.153
# Iteration 158, best_cost so far: 6174.153
# Iteration 159, best_cost so far: 6174.153
# Iteration 160, best_cost so far: 6174.153
# Iteration 161, best_cost so far: 6174.153
# Iteration 162, best_cost so far: 6174.153
# Iteration 163, best_cost so far: 6174.153
# Iteration 164, best_cost so far: 6174.153
# Iteration 165, best_cost so far: 6174.153

# %% [markdown]
# Test 4

# %%
best_result, test = genetic_algorithm_main(test_address="CurveFitting-Tests/CurveFitting_test4.txt", generation_num=500, p_cross=0.65, p_mutate=0.5, p_replace=0.1, pop_size=200, stop_iter=100, expected_val=1)
# Out:
# Iteration 1, best_cost so far: 1364.578
# Iteration 2, best_cost so far: 1364.578
# Iteration 3, best_cost so far: 1364.578
# Iteration 4, best_cost so far: 1364.578
# Iteration 5, best_cost so far: 1364.578
# Iteration 6, best_cost so far: 1364.578
# Iteration 7, best_cost so far: 1364.578
# Iteration 8, best_cost so far: 960.284
# Iteration 9, best_cost so far: 290.336
# Iteration 10, best_cost so far: 290.336
# Iteration 11, best_cost so far: 290.336
# Iteration 12, best_cost so far: 290.336
# Iteration 13, best_cost so far: 290.336
# Iteration 14, best_cost so far: 290.336
# Iteration 15, best_cost so far: 290.336
# Iteration 16, best_cost so far: 276.282
# Iteration 17, best_cost so far: 201.766
# Iteration 18, best_cost so far: 201.766
# Iteration 19, best_cost so far: 201.766
# Iteration 20, best_cost so far: 201.766
# Iteration 21, best_cost so far: 201.766
# Iteration 22, best_cost so far: 201.766
# Iteration 23, best_cost so far: 201.766
# Iteration 24, best_cost so far: 201.766
# Iteration 25, best_cost so far: 137.942
# Iteration 26, best_cost so far: 137.942
# Iteration 27, best_cost so far: 137.942
# Iteration 28, best_cost so far: 137.942
# Iteration 29, best_cost so far: 137.942
# Iteration 30, best_cost so far: 137.942
# Iteration 31, best_cost so far: 137.942
# Iteration 32, best_cost so far: 137.942
# Iteration 33, best_cost so far: 137.942
# Iteration 34, best_cost so far: 137.942
# Iteration 35, best_cost so far: 137.942
# Iteration 36, best_cost so far: 137.942
# Iteration 37, best_cost so far: 111.966
# Iteration 38, best_cost so far: 111.966
# Iteration 39, best_cost so far: 96.777
# Iteration 40, best_cost so far: 96.777
# Iteration 41, best_cost so far: 96.777
# Iteration 42, best_cost so far: 70.479
# Iteration 43, best_cost so far: 70.479
# Iteration 44, best_cost so far: 70.479
# Iteration 45, best_cost so far: 70.479
# Iteration 46, best_cost so far: 70.479
# Iteration 47, best_cost so far: 70.479
# Iteration 48, best_cost so far: 70.479
# Iteration 49, best_cost so far: 70.479
# Iteration 50, best_cost so far: 70.479
# Iteration 51, best_cost so far: 70.479
# Iteration 52, best_cost so far: 70.479
# Iteration 53, best_cost so far: 70.479
# Iteration 54, best_cost so far: 70.479
# Iteration 55, best_cost so far: 70.479
# Iteration 56, best_cost so far: 70.479
# Iteration 57, best_cost so far: 70.479
# Iteration 58, best_cost so far: 70.479
# Iteration 59, best_cost so far: 70.479
# Iteration 60, best_cost so far: 70.479
# Iteration 61, best_cost so far: 70.479
# Iteration 62, best_cost so far: 70.479
# Iteration 63, best_cost so far: 70.479
# Iteration 64, best_cost so far: 70.479
# Iteration 65, best_cost so far: 70.479
# Iteration 66, best_cost so far: 70.479
# Iteration 67, best_cost so far: 70.479
# Iteration 68, best_cost so far: 47.591
# Iteration 69, best_cost so far: 47.591
# Iteration 70, best_cost so far: 47.591
# Iteration 71, best_cost so far: 47.591
# Iteration 72, best_cost so far: 47.591
# Iteration 73, best_cost so far: 47.591
# Iteration 74, best_cost so far: 47.591
# Iteration 75, best_cost so far: 47.591
# Iteration 76, best_cost so far: 47.591
# Iteration 77, best_cost so far: 47.591
# Iteration 78, best_cost so far: 47.591
# Iteration 79, best_cost so far: 47.591
# Iteration 80, best_cost so far: 47.591
# Iteration 81, best_cost so far: 47.591
# Iteration 82, best_cost so far: 47.591
# Iteration 83, best_cost so far: 40.315
# Iteration 84, best_cost so far: 40.315
# Iteration 85, best_cost so far: 40.315
# Iteration 86, best_cost so far: 40.315
# Iteration 87, best_cost so far: 40.315
# Iteration 88, best_cost so far: 40.315
# Iteration 89, best_cost so far: 40.315
# Iteration 90, best_cost so far: 40.315
# Iteration 91, best_cost so far: 40.315
# Iteration 92, best_cost so far: 40.315
# Iteration 93, best_cost so far: 40.315
# Iteration 94, best_cost so far: 40.315
# Iteration 95, best_cost so far: 40.315
# Iteration 96, best_cost so far: 40.315
# Iteration 97, best_cost so far: 26.331
# Iteration 98, best_cost so far: 26.331
# Iteration 99, best_cost so far: 26.331
# Iteration 100, best_cost so far: 26.331
# Iteration 101, best_cost so far: 26.331
# Iteration 102, best_cost so far: 26.331
# Iteration 103, best_cost so far: 26.331
# Iteration 104, best_cost so far: 26.331
# Iteration 105, best_cost so far: 26.331
# Iteration 106, best_cost so far: 26.331
# Iteration 107, best_cost so far: 26.331
# Iteration 108, best_cost so far: 26.331
# Iteration 109, best_cost so far: 26.331
# Iteration 110, best_cost so far: 26.331
# Iteration 111, best_cost so far: 26.331
# Iteration 112, best_cost so far: 26.331
# Iteration 113, best_cost so far: 26.331
# Iteration 114, best_cost so far: 26.331
# Iteration 115, best_cost so far: 26.331
# Iteration 116, best_cost so far: 26.331
# Iteration 117, best_cost so far: 26.331
# Iteration 118, best_cost so far: 26.331
# Iteration 119, best_cost so far: 26.331
# Iteration 120, best_cost so far: 26.331
# Iteration 121, best_cost so far: 26.331
# Iteration 122, best_cost so far: 26.331
# Iteration 123, best_cost so far: 26.331
# Iteration 124, best_cost so far: 26.331
# Iteration 125, best_cost so far: 26.331
# Iteration 126, best_cost so far: 26.331
# Iteration 127, best_cost so far: 26.331
# Iteration 128, best_cost so far: 26.331
# Iteration 129, best_cost so far: 26.331
# Iteration 130, best_cost so far: 26.331
# Iteration 131, best_cost so far: 26.331
# Iteration 132, best_cost so far: 26.331
# Iteration 133, best_cost so far: 26.331
# Iteration 134, best_cost so far: 26.331
# Iteration 135, best_cost so far: 26.331
# Iteration 136, best_cost so far: 26.331
# Iteration 137, best_cost so far: 26.331
# Iteration 138, best_cost so far: 26.331
# Iteration 139, best_cost so far: 26.331
# Iteration 140, best_cost so far: 26.331
# Iteration 141, best_cost so far: 26.331
# Iteration 142, best_cost so far: 26.331
# Iteration 143, best_cost so far: 26.331
# Iteration 144, best_cost so far: 26.331
# Iteration 145, best_cost so far: 26.331
# Iteration 146, best_cost so far: 26.331
# Iteration 147, best_cost so far: 26.331
# Iteration 148, best_cost so far: 26.331
# Iteration 149, best_cost so far: 26.331
# Iteration 150, best_cost so far: 26.331
# Iteration 151, best_cost so far: 26.331
# Iteration 152, best_cost so far: 26.331
# Iteration 153, best_cost so far: 26.331
# Iteration 154, best_cost so far: 26.331
# Iteration 155, best_cost so far: 26.331
# Iteration 156, best_cost so far: 26.331
# Iteration 157, best_cost so far: 26.331
# Iteration 158, best_cost so far: 26.331
# Iteration 159, best_cost so far: 26.331
# Iteration 160, best_cost so far: 26.331
# Iteration 161, best_cost so far: 26.331
# Iteration 162, best_cost so far: 26.331
# Iteration 163, best_cost so far: 26.331
# Iteration 164, best_cost so far: 26.331
# Iteration 165, best_cost so far: 26.331
# Iteration 166, best_cost so far: 26.331
# Iteration 167, best_cost so far: 26.331
# Iteration 168, best_cost so far: 26.331
# Iteration 169, best_cost so far: 26.331
# Iteration 170, best_cost so far: 26.331
# Iteration 171, best_cost so far: 26.331
# Iteration 172, best_cost so far: 26.331
# Iteration 173, best_cost so far: 26.331
# Iteration 174, best_cost so far: 26.331
# Iteration 175, best_cost so far: 26.331
# Iteration 176, best_cost so far: 26.331
# Iteration 177, best_cost so far: 26.331
# Iteration 178, best_cost so far: 26.331
# Iteration 179, best_cost so far: 26.331
# Iteration 180, best_cost so far: 26.331
# Iteration 181, best_cost so far: 26.331
# Iteration 182, best_cost so far: 26.331
# Iteration 183, best_cost so far: 26.331
# Iteration 184, best_cost so far: 26.331
# Iteration 185, best_cost so far: 26.331
# Iteration 186, best_cost so far: 26.331
# Iteration 187, best_cost so far: 26.331
# Iteration 188, best_cost so far: 26.331
# Iteration 189, best_cost so far: 26.331
# Iteration 190, best_cost so far: 26.331
# Iteration 191, best_cost so far: 26.331
# Iteration 192, best_cost so far: 26.331
# Iteration 193, best_cost so far: 26.331
# Iteration 194, best_cost so far: 26.331
# Iteration 195, best_cost so far: 26.331
# Iteration 196, best_cost so far: 26.331
# Iteration 197, best_cost so far: 26.331
# Iteration 198, best_cost so far: 26.331

# %% [markdown]
# ### Memetic (curve fitting)

# %%
def memetic_algorithm_main(test_address, generation_num, p_cross, p_mutate, p_neighbor, p_replace, pop_size, stop_iter, expected_val, tornoment_N=3):
    # save best seen result
    best_cost = math.inf
    best_result = []

    # load test case
    testcase = Data(test_address)
    testcase.load_data()

    # step 1: create first population
    population = Population(testcase, pop_size=pop_size)
    population.initialize_population()

    iteration_without_change, g_num = 0, 0
    # iteration of running algorithm (number of generations)
    while True:
        g_num += 1 # iteration number
        children_population = Population(testcase, pop_size=pop_size)
        counter = 0
        # create as many children as parents population
        while counter < pop_size:

            # step 2: parent selection for crossover
            father1, mother1 = population.parent_selection_rank_based()
            father2, mother2 = population.parent_selection_rank_based()

            # step 3: crossover 2 selected parents with p_cross
            e_cross = random.random()
            if e_cross < p_cross:
                child1 = population.blx_alpha_crossover(father1, mother1, alpha=0.6)
                child2 = population.blx_alpha_crossover(father2, mother2, alpha=0.65)
                counter += 2

                # step 4: mutate children with p_mutate
                e_mutate1 = random.random()
                if e_mutate1 < p_mutate:
                    child1.mutation()
                e_mutate2 = random.random()
                if e_mutate2 < p_mutate:
                    child2.mutation()

                # step 5: local search on children and update fitness
                e_neighbor1 = random.random()
                if e_neighbor1 < p_neighbor:
                    genei = child1.local_search()
                else:
                    genei = child1
                e_neighbor2 = random.random()
                if e_neighbor2 < p_neighbor:
                    genej = child2.local_search()
                else:
                    genej = child2


                # add generated children to children population
                children_population.population.append(genei)
                children_population.population.append(genej)

        # step 6: population replacement
        parent_values = []
        child_values  = []
        for i in range(pop_size):             # save all values of parents and children in 2 value lists
            x = population.population[i].fitness
            y = children_population.population[i].fitness
            parent_values.append(x)
            child_values.append(y)

        num_replace = p_replace * pop_size    # find the number of parents that should be replaced with children in population

        # replace num_replace worst parent with best children
        for i in range(int(num_replace)):        # replace as the size of replacements in population
            max_parent_ind = parent_values.index(max(parent_values))    # find the worst parent
            min_child_ind  = child_values.index(min(child_values))      # find best children

            population.population.pop(max_parent_ind)      # remove worst parent from population
            population.population.append(children_population.population[min_child_ind])  # add best children to population

            children_population.population.pop(min_child_ind)  # remove best children from population of children
            parent_values.pop(max_parent_ind)   # remove worst parent value from parents values
            child_values.pop(min_child_ind)  # remove best children value from children values

        # step 7: population fitness check, find the best result in population
        flag = False
        for i in range(pop_size):
            if population.population[i].fitness < best_cost:
                best_cost   = population.population[i].fitness
                best_result = population.population[i].gene.copy()
                iteration_without_change = 0
                flag = True
        if not flag:
            iteration_without_change += 1

        print(f"Iteration {g_num}, best_cost so far: {np.round(best_cost, 3)}")

        # step 7: check stop condition
        if best_cost < expected_val or iteration_without_change > stop_iter:
            break


    return best_result, testcase

# %% [markdown]
# Test 1

# %%
best_result, test = memetic_algorithm_main(test_address="CurveFitting_test1.txt", generation_num=500, p_cross=0.65, p_mutate=0.5, p_replace=0.1, pop_size=100, stop_iter=100, expected_val=100, p_neighbor=0.5)
# Out:
# Iteration 1, best_cost so far: 39265.443
# Iteration 2, best_cost so far: 24226.44
# Iteration 3, best_cost so far: 24226.44
# Iteration 4, best_cost so far: 24226.44
# Iteration 5, best_cost so far: 19464.328
# Iteration 6, best_cost so far: 12095.896
# Iteration 7, best_cost so far: 12095.896
# Iteration 8, best_cost so far: 12095.896
# Iteration 9, best_cost so far: 12095.896
# Iteration 10, best_cost so far: 12095.896
# Iteration 11, best_cost so far: 7489.319
# Iteration 12, best_cost so far: 7489.319
# Iteration 13, best_cost so far: 7489.319
# Iteration 14, best_cost so far: 5187.515
# Iteration 15, best_cost so far: 5187.515
# Iteration 16, best_cost so far: 5187.515
# Iteration 17, best_cost so far: 5187.515
# Iteration 18, best_cost so far: 5187.515
# Iteration 19, best_cost so far: 5187.515
# Iteration 20, best_cost so far: 5187.515
# Iteration 21, best_cost so far: 2939.544
# Iteration 22, best_cost so far: 2939.544
# Iteration 23, best_cost so far: 2939.544
# Iteration 24, best_cost so far: 586.494
# Iteration 25, best_cost so far: 586.494
# Iteration 26, best_cost so far: 586.494
# Iteration 27, best_cost so far: 586.494
# Iteration 28, best_cost so far: 586.494
# Iteration 29, best_cost so far: 586.494
# Iteration 30, best_cost so far: 586.494
# Iteration 31, best_cost so far: 586.494
# Iteration 32, best_cost so far: 586.494
# Iteration 33, best_cost so far: 466.36
# Iteration 34, best_cost so far: 466.36
# Iteration 35, best_cost so far: 466.36
# Iteration 36, best_cost so far: 466.36
# Iteration 37, best_cost so far: 466.36
# Iteration 38, best_cost so far: 466.36
# Iteration 39, best_cost so far: 466.36
# Iteration 40, best_cost so far: 466.36
# Iteration 41, best_cost so far: 466.36
# Iteration 42, best_cost so far: 466.36
# Iteration 43, best_cost so far: 466.36
# Iteration 44, best_cost so far: 466.36
# Iteration 45, best_cost so far: 466.36
# Iteration 46, best_cost so far: 466.36
# Iteration 47, best_cost so far: 242.082
# Iteration 48, best_cost so far: 242.082
# Iteration 49, best_cost so far: 242.082
# Iteration 50, best_cost so far: 242.082
# Iteration 51, best_cost so far: 242.082
# Iteration 52, best_cost so far: 242.082
# Iteration 53, best_cost so far: 242.082
# Iteration 54, best_cost so far: 242.082
# Iteration 55, best_cost so far: 242.082
# Iteration 56, best_cost so far: 242.082
# Iteration 57, best_cost so far: 242.082
# Iteration 58, best_cost so far: 242.082
# Iteration 59, best_cost so far: 242.082
# Iteration 60, best_cost so far: 242.082
# Iteration 61, best_cost so far: 242.082
# Iteration 62, best_cost so far: 242.082
# Iteration 63, best_cost so far: 242.082
# Iteration 64, best_cost so far: 242.082
# Iteration 65, best_cost so far: 242.082
# Iteration 66, best_cost so far: 242.082
# Iteration 67, best_cost so far: 242.082
# Iteration 68, best_cost so far: 192.999
# Iteration 69, best_cost so far: 184.261
# Iteration 70, best_cost so far: 184.261
# Iteration 71, best_cost so far: 184.261
# Iteration 72, best_cost so far: 184.261
# Iteration 73, best_cost so far: 184.261
# Iteration 74, best_cost so far: 184.261
# Iteration 75, best_cost so far: 184.261
# Iteration 76, best_cost so far: 184.261
# Iteration 77, best_cost so far: 184.261
# Iteration 78, best_cost so far: 184.261
# Iteration 79, best_cost so far: 184.261
# Iteration 80, best_cost so far: 184.261
# Iteration 81, best_cost so far: 184.261
# Iteration 82, best_cost so far: 184.261
# Iteration 83, best_cost so far: 166.411
# Iteration 84, best_cost so far: 166.411
# Iteration 85, best_cost so far: 166.411
# Iteration 86, best_cost so far: 166.411
# Iteration 87, best_cost so far: 166.411
# Iteration 88, best_cost so far: 166.411
# Iteration 89, best_cost so far: 166.411
# Iteration 90, best_cost so far: 166.411
# Iteration 91, best_cost so far: 166.411
# Iteration 92, best_cost so far: 166.411
# Iteration 93, best_cost so far: 166.411
# Iteration 94, best_cost so far: 166.411
# Iteration 95, best_cost so far: 166.411
# Iteration 96, best_cost so far: 166.411
# Iteration 97, best_cost so far: 166.411
# Iteration 98, best_cost so far: 166.411
# Iteration 99, best_cost so far: 166.411
# Iteration 100, best_cost so far: 166.411
# Iteration 101, best_cost so far: 166.411
# Iteration 102, best_cost so far: 166.411
# Iteration 103, best_cost so far: 166.411
# Iteration 104, best_cost so far: 166.411
# Iteration 105, best_cost so far: 166.411
# Iteration 106, best_cost so far: 166.411
# Iteration 107, best_cost so far: 166.411
# Iteration 108, best_cost so far: 166.411
# Iteration 109, best_cost so far: 139.431
# Iteration 110, best_cost so far: 139.431
# Iteration 111, best_cost so far: 139.431
# Iteration 112, best_cost so far: 139.431
# Iteration 113, best_cost so far: 139.431
# Iteration 114, best_cost so far: 139.431
# Iteration 115, best_cost so far: 139.431
# Iteration 116, best_cost so far: 139.431
# Iteration 117, best_cost so far: 139.431
# Iteration 118, best_cost so far: 139.431
# Iteration 119, best_cost so far: 139.431
# Iteration 120, best_cost so far: 139.431
# Iteration 121, best_cost so far: 139.431
# Iteration 122, best_cost so far: 139.431
# Iteration 123, best_cost so far: 139.431
# Iteration 124, best_cost so far: 139.431
# Iteration 125, best_cost so far: 139.431
# Iteration 126, best_cost so far: 139.431
# Iteration 127, best_cost so far: 139.431
# Iteration 128, best_cost so far: 139.431
# Iteration 129, best_cost so far: 139.431
# Iteration 130, best_cost so far: 139.431
# Iteration 131, best_cost so far: 139.431
# Iteration 132, best_cost so far: 139.431
# Iteration 133, best_cost so far: 139.431
# Iteration 134, best_cost so far: 139.431
# Iteration 135, best_cost so far: 139.431
# Iteration 136, best_cost so far: 139.431
# Iteration 137, best_cost so far: 139.431
# Iteration 138, best_cost so far: 139.431
# Iteration 139, best_cost so far: 139.431
# Iteration 140, best_cost so far: 139.431
# Iteration 141, best_cost so far: 139.431
# Iteration 142, best_cost so far: 139.431
# Iteration 143, best_cost so far: 139.431
# Iteration 144, best_cost so far: 139.431
# Iteration 145, best_cost so far: 139.431
# Iteration 146, best_cost so far: 139.431
# Iteration 147, best_cost so far: 139.431
# Iteration 148, best_cost so far: 139.431
# Iteration 149, best_cost so far: 139.431
# Iteration 150, best_cost so far: 139.431
# Iteration 151, best_cost so far: 139.431
# Iteration 152, best_cost so far: 139.431
# Iteration 153, best_cost so far: 139.431
# Iteration 154, best_cost so far: 139.431
# Iteration 155, best_cost so far: 139.431
# Iteration 156, best_cost so far: 139.431
# Iteration 157, best_cost so far: 139.431
# Iteration 158, best_cost so far: 139.431
# Iteration 159, best_cost so far: 139.431
# Iteration 160, best_cost so far: 139.431
# Iteration 161, best_cost so far: 139.431
# Iteration 162, best_cost so far: 139.431
# Iteration 163, best_cost so far: 139.431
# Iteration 164, best_cost so far: 139.431
# Iteration 165, best_cost so far: 139.431
# Iteration 166, best_cost so far: 139.431
# Iteration 167, best_cost so far: 139.431
# Iteration 168, best_cost so far: 139.431
# Iteration 169, best_cost so far: 139.431
# Iteration 170, best_cost so far: 139.431
# Iteration 171, best_cost so far: 139.431
# Iteration 172, best_cost so far: 139.431
# Iteration 173, best_cost so far: 139.431
# Iteration 174, best_cost so far: 139.431
# Iteration 175, best_cost so far: 139.431
# Iteration 176, best_cost so far: 139.431
# Iteration 177, best_cost so far: 139.431
# Iteration 178, best_cost so far: 139.431
# Iteration 179, best_cost so far: 139.431
# Iteration 180, best_cost so far: 139.431
# Iteration 181, best_cost so far: 139.431
# Iteration 182, best_cost so far: 139.431
# Iteration 183, best_cost so far: 139.431
# Iteration 184, best_cost so far: 139.431
# Iteration 185, best_cost so far: 139.431
# Iteration 186, best_cost so far: 139.431
# Iteration 187, best_cost so far: 139.431
# Iteration 188, best_cost so far: 139.431
# Iteration 189, best_cost so far: 139.431
# Iteration 190, best_cost so far: 139.431
# Iteration 191, best_cost so far: 139.431
# Iteration 192, best_cost so far: 139.431
# Iteration 193, best_cost so far: 139.431
# Iteration 194, best_cost so far: 139.431
# Iteration 195, best_cost so far: 139.431
# Iteration 196, best_cost so far: 139.431
# Iteration 197, best_cost so far: 139.431
# Iteration 198, best_cost so far: 139.431
# Iteration 199, best_cost so far: 139.431
# Iteration 200, best_cost so far: 139.431
# Iteration 201, best_cost so far: 139.431
# Iteration 202, best_cost so far: 139.431
# Iteration 203, best_cost so far: 135.289
# Iteration 204, best_cost so far: 135.289
# Iteration 205, best_cost so far: 135.289
# Iteration 206, best_cost so far: 135.289
# Iteration 207, best_cost so far: 135.289
# Iteration 208, best_cost so far: 135.289
# Iteration 209, best_cost so far: 135.289
# Iteration 210, best_cost so far: 135.289
# Iteration 211, best_cost so far: 134.846
# Iteration 212, best_cost so far: 134.846
# Iteration 213, best_cost so far: 134.846
# Iteration 214, best_cost so far: 134.846
# Iteration 215, best_cost so far: 134.846
# Iteration 216, best_cost so far: 134.846
# Iteration 217, best_cost so far: 134.846
# Iteration 218, best_cost so far: 134.846
# Iteration 219, best_cost so far: 134.846
# Iteration 220, best_cost so far: 134.846
# Iteration 221, best_cost so far: 134.846
# Iteration 222, best_cost so far: 134.846
# Iteration 223, best_cost so far: 134.846
# Iteration 224, best_cost so far: 134.846
# Iteration 225, best_cost so far: 134.846
# Iteration 226, best_cost so far: 134.846
# Iteration 227, best_cost so far: 134.846
# Iteration 228, best_cost so far: 134.846
# Iteration 229, best_cost so far: 134.846
# Iteration 230, best_cost so far: 134.846
# Iteration 231, best_cost so far: 134.846
# Iteration 232, best_cost so far: 134.846
# Iteration 233, best_cost so far: 134.846
# Iteration 234, best_cost so far: 134.846
# Iteration 235, best_cost so far: 134.846
# Iteration 236, best_cost so far: 134.846
# Iteration 237, best_cost so far: 134.846
# Iteration 238, best_cost so far: 134.846
# Iteration 239, best_cost so far: 134.846
# Iteration 240, best_cost so far: 134.846
# Iteration 241, best_cost so far: 134.846
# Iteration 242, best_cost so far: 134.846
# Iteration 243, best_cost so far: 134.846
# Iteration 244, best_cost so far: 134.846
# Iteration 245, best_cost so far: 134.846
# Iteration 246, best_cost so far: 134.846
# Iteration 247, best_cost so far: 134.846
# Iteration 248, best_cost so far: 134.846
# Iteration 249, best_cost so far: 134.846
# Iteration 250, best_cost so far: 133.86
# Iteration 251, best_cost so far: 131.23
# Iteration 252, best_cost so far: 131.23
# Iteration 253, best_cost so far: 131.23
# Iteration 254, best_cost so far: 131.23
# Iteration 255, best_cost so far: 131.23
# Iteration 256, best_cost so far: 131.23
# Iteration 257, best_cost so far: 131.23
# Iteration 258, best_cost so far: 131.23
# Iteration 259, best_cost so far: 131.23
# Iteration 260, best_cost so far: 131.23
# Iteration 261, best_cost so far: 131.23
# Iteration 262, best_cost so far: 131.23
# Iteration 263, best_cost so far: 131.23
# Iteration 264, best_cost so far: 131.23
# Iteration 265, best_cost so far: 131.23
# Iteration 266, best_cost so far: 131.23
# Iteration 267, best_cost so far: 131.23
# Iteration 268, best_cost so far: 131.23
# Iteration 269, best_cost so far: 131.23
# Iteration 270, best_cost so far: 131.23
# Iteration 271, best_cost so far: 131.23
# Iteration 272, best_cost so far: 131.23
# Iteration 273, best_cost so far: 131.23
# Iteration 274, best_cost so far: 131.23
# Iteration 275, best_cost so far: 131.23
# Iteration 276, best_cost so far: 131.23
# Iteration 277, best_cost so far: 131.23
# Iteration 278, best_cost so far: 131.23
# Iteration 279, best_cost so far: 131.23
# Iteration 280, best_cost so far: 131.23
# Iteration 281, best_cost so far: 131.23
# Iteration 282, best_cost so far: 131.23
# Iteration 283, best_cost so far: 131.23
# Iteration 284, best_cost so far: 131.23
# Iteration 285, best_cost so far: 131.23
# Iteration 286, best_cost so far: 131.23
# Iteration 287, best_cost so far: 131.23
# Iteration 288, best_cost so far: 131.23
# Iteration 289, best_cost so far: 131.23
# Iteration 290, best_cost so far: 131.23
# Iteration 291, best_cost so far: 131.23
# Iteration 292, best_cost so far: 131.23
# Iteration 293, best_cost so far: 131.23
# Iteration 294, best_cost so far: 131.23
# Iteration 295, best_cost so far: 131.23
# Iteration 296, best_cost so far: 131.23
# Iteration 297, best_cost so far: 131.23
# Iteration 298, best_cost so far: 131.23
# Iteration 299, best_cost so far: 131.23
# Iteration 300, best_cost so far: 131.23
# Iteration 301, best_cost so far: 131.23
# Iteration 302, best_cost so far: 131.23
# Iteration 303, best_cost so far: 131.23
# Iteration 304, best_cost so far: 131.23
# Iteration 305, best_cost so far: 131.23
# Iteration 306, best_cost so far: 131.23
# Iteration 307, best_cost so far: 131.23
# Iteration 308, best_cost so far: 131.23
# Iteration 309, best_cost so far: 131.23
# Iteration 310, best_cost so far: 131.23
# Iteration 311, best_cost so far: 131.23
# Iteration 312, best_cost so far: 131.23
# Iteration 313, best_cost so far: 131.23
# Iteration 314, best_cost so far: 131.23
# Iteration 315, best_cost so far: 131.23
# Iteration 316, best_cost so far: 131.23
# Iteration 317, best_cost so far: 131.23
# Iteration 318, best_cost so far: 131.23
# Iteration 319, best_cost so far: 131.23
# Iteration 320, best_cost so far: 131.23
# Iteration 321, best_cost so far: 131.23
# Iteration 322, best_cost so far: 131.23
# Iteration 323, best_cost so far: 131.23
# Iteration 324, best_cost so far: 131.23
# Iteration 325, best_cost so far: 131.23
# Iteration 326, best_cost so far: 131.23
# Iteration 327, best_cost so far: 131.23
# Iteration 328, best_cost so far: 131.23
# Iteration 329, best_cost so far: 131.23
# Iteration 330, best_cost so far: 131.23
# Iteration 331, best_cost so far: 131.23
# Iteration 332, best_cost so far: 131.23
# Iteration 333, best_cost so far: 131.23
# Iteration 334, best_cost so far: 131.23
# Iteration 335, best_cost so far: 131.23
# Iteration 336, best_cost so far: 131.23
# Iteration 337, best_cost so far: 131.23
# Iteration 338, best_cost so far: 131.23
# Iteration 339, best_cost so far: 131.23
# Iteration 340, best_cost so far: 131.23
# Iteration 341, best_cost so far: 131.23
# Iteration 342, best_cost so far: 131.23
# Iteration 343, best_cost so far: 131.23
# Iteration 344, best_cost so far: 131.23
# Iteration 345, best_cost so far: 131.23
# Iteration 346, best_cost so far: 131.23
# Iteration 347, best_cost so far: 131.23
# Iteration 348, best_cost so far: 131.23
# Iteration 349, best_cost so far: 131.23
# Iteration 350, best_cost so far: 131.23
# Iteration 351, best_cost so far: 131.23
# Iteration 352, best_cost so far: 131.23

# %% [markdown]
# Test 2

# %%
best_result, test = memetic_algorithm_main(test_address="CurveFitting_test2.txt", generation_num=500, p_cross=0.65, p_mutate=0.5, p_replace=0.1, pop_size=100, stop_iter=100, expected_val=100, p_neighbor=0.5)
# Out:
# Iteration 1, best_cost so far: 12399.29
# Iteration 2, best_cost so far: 12399.29
# Iteration 3, best_cost so far: 9332.541
# Iteration 4, best_cost so far: 3688.174
# Iteration 5, best_cost so far: 3688.174
# Iteration 6, best_cost so far: 3688.174
# Iteration 7, best_cost so far: 3688.174
# Iteration 8, best_cost so far: 3688.174
# Iteration 9, best_cost so far: 3688.174
# Iteration 10, best_cost so far: 3688.174
# Iteration 11, best_cost so far: 3399.822
# Iteration 12, best_cost so far: 3399.822
# Iteration 13, best_cost so far: 3399.822
# Iteration 14, best_cost so far: 1554.847
# Iteration 15, best_cost so far: 882.612
# Iteration 16, best_cost so far: 882.612
# Iteration 17, best_cost so far: 882.612
# Iteration 18, best_cost so far: 882.612
# Iteration 19, best_cost so far: 773.829
# Iteration 20, best_cost so far: 773.829
# Iteration 21, best_cost so far: 773.829
# Iteration 22, best_cost so far: 773.829
# Iteration 23, best_cost so far: 773.829
# Iteration 24, best_cost so far: 773.829
# Iteration 25, best_cost so far: 773.829
# Iteration 26, best_cost so far: 773.829
# Iteration 27, best_cost so far: 773.829
# Iteration 28, best_cost so far: 773.829
# Iteration 29, best_cost so far: 773.829
# Iteration 30, best_cost so far: 773.829
# Iteration 31, best_cost so far: 728.905
# Iteration 32, best_cost so far: 728.905
# Iteration 33, best_cost so far: 728.905
# Iteration 34, best_cost so far: 728.905
# Iteration 35, best_cost so far: 728.905
# Iteration 36, best_cost so far: 728.905
# Iteration 37, best_cost so far: 728.905
# Iteration 38, best_cost so far: 728.905
# Iteration 39, best_cost so far: 728.905
# Iteration 40, best_cost so far: 728.905
# Iteration 41, best_cost so far: 619.496
# Iteration 42, best_cost so far: 619.496
# Iteration 43, best_cost so far: 619.496
# Iteration 44, best_cost so far: 619.496
# Iteration 45, best_cost so far: 619.496
# Iteration 46, best_cost so far: 619.496
# Iteration 47, best_cost so far: 619.496
# Iteration 48, best_cost so far: 619.496
# Iteration 49, best_cost so far: 472.374
# Iteration 50, best_cost so far: 472.374
# Iteration 51, best_cost so far: 364.083
# Iteration 52, best_cost so far: 364.083
# Iteration 53, best_cost so far: 364.083
# Iteration 54, best_cost so far: 364.083
# Iteration 55, best_cost so far: 364.083
# Iteration 56, best_cost so far: 364.083
# Iteration 57, best_cost so far: 364.083
# Iteration 58, best_cost so far: 364.083
# Iteration 59, best_cost so far: 364.083
# Iteration 60, best_cost so far: 364.083
# Iteration 61, best_cost so far: 364.083
# Iteration 62, best_cost so far: 364.083
# Iteration 63, best_cost so far: 364.083
# Iteration 64, best_cost so far: 364.083
# Iteration 65, best_cost so far: 364.083
# Iteration 66, best_cost so far: 364.083
# Iteration 67, best_cost so far: 364.083
# Iteration 68, best_cost so far: 364.083
# Iteration 69, best_cost so far: 364.083
# Iteration 70, best_cost so far: 364.083
# Iteration 71, best_cost so far: 364.083
# Iteration 72, best_cost so far: 364.083
# Iteration 73, best_cost so far: 364.083
# Iteration 74, best_cost so far: 364.083
# Iteration 75, best_cost so far: 364.083
# Iteration 76, best_cost so far: 364.083
# Iteration 77, best_cost so far: 364.083
# Iteration 78, best_cost so far: 364.083
# Iteration 79, best_cost so far: 364.083
# Iteration 80, best_cost so far: 364.083
# Iteration 81, best_cost so far: 364.083
# Iteration 82, best_cost so far: 364.083
# Iteration 83, best_cost so far: 364.083
# Iteration 84, best_cost so far: 364.083
# Iteration 85, best_cost so far: 364.083
# Iteration 86, best_cost so far: 364.083
# Iteration 87, best_cost so far: 364.083
# Iteration 88, best_cost so far: 364.083
# Iteration 89, best_cost so far: 364.083
# Iteration 90, best_cost so far: 364.083
# Iteration 91, best_cost so far: 364.083
# Iteration 92, best_cost so far: 364.083
# Iteration 93, best_cost so far: 364.083
# Iteration 94, best_cost so far: 364.083
# Iteration 95, best_cost so far: 364.083
# Iteration 96, best_cost so far: 364.083
# Iteration 97, best_cost so far: 364.083
# Iteration 98, best_cost so far: 364.083
# Iteration 99, best_cost so far: 364.083
# Iteration 100, best_cost so far: 364.083
# Iteration 101, best_cost so far: 364.083
# Iteration 102, best_cost so far: 364.083
# Iteration 103, best_cost so far: 364.083
# Iteration 104, best_cost so far: 364.083
# Iteration 105, best_cost so far: 364.083
# Iteration 106, best_cost so far: 364.083
# Iteration 107, best_cost so far: 364.083
# Iteration 108, best_cost so far: 364.083
# Iteration 109, best_cost so far: 364.083
# Iteration 110, best_cost so far: 364.083
# Iteration 111, best_cost so far: 364.083
# Iteration 112, best_cost so far: 364.083
# Iteration 113, best_cost so far: 364.083
# Iteration 114, best_cost so far: 364.083
# Iteration 115, best_cost so far: 364.083
# Iteration 116, best_cost so far: 364.083
# Iteration 117, best_cost so far: 364.083
# Iteration 118, best_cost so far: 364.083
# Iteration 119, best_cost so far: 364.083
# Iteration 120, best_cost so far: 364.083
# Iteration 121, best_cost so far: 364.083
# Iteration 122, best_cost so far: 364.083
# Iteration 123, best_cost so far: 364.083
# Iteration 124, best_cost so far: 364.083
# Iteration 125, best_cost so far: 342.045
# Iteration 126, best_cost so far: 342.045
# Iteration 127, best_cost so far: 342.045
# Iteration 128, best_cost so far: 342.045
# Iteration 129, best_cost so far: 342.045
# Iteration 130, best_cost so far: 342.045
# Iteration 131, best_cost so far: 342.045
# Iteration 132, best_cost so far: 342.045
# Iteration 133, best_cost so far: 342.045
# Iteration 134, best_cost so far: 342.045
# Iteration 135, best_cost so far: 342.045
# Iteration 136, best_cost so far: 342.045
# Iteration 137, best_cost so far: 342.045
# Iteration 138, best_cost so far: 342.045
# Iteration 139, best_cost so far: 342.045
# Iteration 140, best_cost so far: 342.045
# Iteration 141, best_cost so far: 342.045
# Iteration 142, best_cost so far: 342.045
# Iteration 143, best_cost so far: 342.045
# Iteration 144, best_cost so far: 342.045
# Iteration 145, best_cost so far: 342.045
# Iteration 146, best_cost so far: 342.045
# Iteration 147, best_cost so far: 342.045
# Iteration 148, best_cost so far: 342.045
# Iteration 149, best_cost so far: 342.045
# Iteration 150, best_cost so far: 342.045
# Iteration 151, best_cost so far: 342.045
# Iteration 152, best_cost so far: 342.045
# Iteration 153, best_cost so far: 342.045
# Iteration 154, best_cost so far: 342.045
# Iteration 155, best_cost so far: 342.045
# Iteration 156, best_cost so far: 342.045
# Iteration 157, best_cost so far: 342.045
# Iteration 158, best_cost so far: 342.045
# Iteration 159, best_cost so far: 342.045
# Iteration 160, best_cost so far: 342.045
# Iteration 161, best_cost so far: 342.045
# Iteration 162, best_cost so far: 342.045
# Iteration 163, best_cost so far: 342.045
# Iteration 164, best_cost so far: 342.045
# Iteration 165, best_cost so far: 342.045
# Iteration 166, best_cost so far: 342.045
# Iteration 167, best_cost so far: 342.045
# Iteration 168, best_cost so far: 342.045
# Iteration 169, best_cost so far: 342.045
# Iteration 170, best_cost so far: 342.045
# Iteration 171, best_cost so far: 342.045
# Iteration 172, best_cost so far: 342.045
# Iteration 173, best_cost so far: 342.045
# Iteration 174, best_cost so far: 342.045
# Iteration 175, best_cost so far: 342.045
# Iteration 176, best_cost so far: 342.045
# Iteration 177, best_cost so far: 342.045
# Iteration 178, best_cost so far: 342.045
# Iteration 179, best_cost so far: 342.045
# Iteration 180, best_cost so far: 342.045
# Iteration 181, best_cost so far: 342.045
# Iteration 182, best_cost so far: 342.045
# Iteration 183, best_cost so far: 342.045
# Iteration 184, best_cost so far: 342.045
# Iteration 185, best_cost so far: 342.045
# Iteration 186, best_cost so far: 342.045
# Iteration 187, best_cost so far: 342.045
# Iteration 188, best_cost so far: 342.045
# Iteration 189, best_cost so far: 342.045
# Iteration 190, best_cost so far: 342.045
# Iteration 191, best_cost so far: 342.045
# Iteration 192, best_cost so far: 342.045
# Iteration 193, best_cost so far: 342.045
# Iteration 194, best_cost so far: 342.045
# Iteration 195, best_cost so far: 342.045
# Iteration 196, best_cost so far: 342.045
# Iteration 197, best_cost so far: 342.045
# Iteration 198, best_cost so far: 342.045
# Iteration 199, best_cost so far: 342.045
# Iteration 200, best_cost so far: 342.045
# Iteration 201, best_cost so far: 342.045
# Iteration 202, best_cost so far: 342.045
# Iteration 203, best_cost so far: 342.045
# Iteration 204, best_cost so far: 342.045
# Iteration 205, best_cost so far: 342.045
# Iteration 206, best_cost so far: 342.045
# Iteration 207, best_cost so far: 342.045
# Iteration 208, best_cost so far: 342.045
# Iteration 209, best_cost so far: 342.045
# Iteration 210, best_cost so far: 342.045
# Iteration 211, best_cost so far: 342.045
# Iteration 212, best_cost so far: 342.045
# Iteration 213, best_cost so far: 342.045
# Iteration 214, best_cost so far: 342.045
# Iteration 215, best_cost so far: 342.045
# Iteration 216, best_cost so far: 342.045
# Iteration 217, best_cost so far: 342.045
# Iteration 218, best_cost so far: 342.045
# Iteration 219, best_cost so far: 342.045
# Iteration 220, best_cost so far: 342.045
# Iteration 221, best_cost so far: 342.045
# Iteration 222, best_cost so far: 342.045
# Iteration 223, best_cost so far: 342.045
# Iteration 224, best_cost so far: 342.045
# Iteration 225, best_cost so far: 342.045
# Iteration 226, best_cost so far: 342.045

# %% [markdown]
# Test 3

# %%
best_result, test = memetic_algorithm_main(test_address="CurveFitting_test3.txt", generation_num=500, p_cross=0.65, p_mutate=0.5, p_replace=0.1, pop_size=100, stop_iter=50, expected_val=100, p_neighbor=0.5)
# Out:
# Iteration 1, best_cost so far: 9180.985
# Iteration 2, best_cost so far: 9180.985
# Iteration 3, best_cost so far: 9180.985
# Iteration 4, best_cost so far: 9180.985
# Iteration 5, best_cost so far: 9180.985
# Iteration 6, best_cost so far: 8571.951
# Iteration 7, best_cost so far: 7897.773
# Iteration 8, best_cost so far: 7585.278
# Iteration 9, best_cost so far: 2364.401
# Iteration 10, best_cost so far: 2364.401
# Iteration 11, best_cost so far: 2364.401
# Iteration 12, best_cost so far: 2364.401
# Iteration 13, best_cost so far: 2364.401
# Iteration 14, best_cost so far: 2364.401
# Iteration 15, best_cost so far: 2364.401
# Iteration 16, best_cost so far: 2364.401
# Iteration 17, best_cost so far: 2364.401
# Iteration 18, best_cost so far: 2364.401
# Iteration 19, best_cost so far: 2364.401
# Iteration 20, best_cost so far: 2364.401
# Iteration 21, best_cost so far: 2364.401
# Iteration 22, best_cost so far: 2364.401
# Iteration 23, best_cost so far: 2364.401
# Iteration 24, best_cost so far: 2364.401
# Iteration 25, best_cost so far: 2364.401
# Iteration 26, best_cost so far: 2364.401
# Iteration 27, best_cost so far: 2364.401
# Iteration 28, best_cost so far: 2364.401
# Iteration 29, best_cost so far: 2364.401
# Iteration 30, best_cost so far: 2364.401
# Iteration 31, best_cost so far: 2364.401
# Iteration 32, best_cost so far: 2364.401
# Iteration 33, best_cost so far: 2364.401
# Iteration 34, best_cost so far: 2364.401
# Iteration 35, best_cost so far: 2364.401
# Iteration 36, best_cost so far: 2364.401
# Iteration 37, best_cost so far: 2364.401
# Iteration 38, best_cost so far: 2364.401
# Iteration 39, best_cost so far: 2364.401
# Iteration 40, best_cost so far: 2364.401
# Iteration 41, best_cost so far: 2364.401
# Iteration 42, best_cost so far: 2364.401
# Iteration 43, best_cost so far: 2364.401
# Iteration 44, best_cost so far: 2364.401
# Iteration 45, best_cost so far: 2364.401
# Iteration 46, best_cost so far: 2364.401
# Iteration 47, best_cost so far: 2364.401
# Iteration 48, best_cost so far: 2364.401
# Iteration 49, best_cost so far: 2364.401
# Iteration 50, best_cost so far: 2364.401
# Iteration 51, best_cost so far: 2364.401
# Iteration 52, best_cost so far: 2364.401
# Iteration 53, best_cost so far: 2364.401
# Iteration 54, best_cost so far: 2364.401
# Iteration 55, best_cost so far: 2364.401
# Iteration 56, best_cost so far: 2364.401
# Iteration 57, best_cost so far: 2364.401
# Iteration 58, best_cost so far: 2364.401
# Iteration 59, best_cost so far: 2364.401
# Iteration 60, best_cost so far: 2364.401

# %% [markdown]
# Test 4

# %%
best_result, test = memetic_algorithm_main(test_address="CurveFitting_test4.txt", generation_num=500, p_cross=0.65, p_mutate=0.5, p_replace=0.1, pop_size=100, stop_iter=100, expected_val=1, p_neighbor=0.5)
# Out:
# Iteration 1, best_cost so far: 13606.163
# Iteration 2, best_cost so far: 12395.274
# Iteration 3, best_cost so far: 6305.843
# Iteration 4, best_cost so far: 6305.843
# Iteration 5, best_cost so far: 6194.466
# Iteration 6, best_cost so far: 4160.299
# Iteration 7, best_cost so far: 3015.677
# Iteration 8, best_cost so far: 3015.677
# Iteration 9, best_cost so far: 3015.677
# Iteration 10, best_cost so far: 3015.677
# Iteration 11, best_cost so far: 3015.677
# Iteration 12, best_cost so far: 3015.677
# Iteration 13, best_cost so far: 3015.677
# Iteration 14, best_cost so far: 3015.677
# Iteration 15, best_cost so far: 3015.677
# Iteration 16, best_cost so far: 2588.949
# Iteration 17, best_cost so far: 1798.803
# Iteration 18, best_cost so far: 590.326
# Iteration 19, best_cost so far: 590.326
# Iteration 20, best_cost so far: 590.326
# Iteration 21, best_cost so far: 590.326
# Iteration 22, best_cost so far: 590.326
# Iteration 23, best_cost so far: 590.326
# Iteration 24, best_cost so far: 590.326
# Iteration 25, best_cost so far: 590.326
# Iteration 26, best_cost so far: 590.326
# Iteration 27, best_cost so far: 429.01
# Iteration 28, best_cost so far: 429.01
# Iteration 29, best_cost so far: 429.01
# Iteration 30, best_cost so far: 429.01
# Iteration 31, best_cost so far: 429.01
# Iteration 32, best_cost so far: 429.01
# Iteration 33, best_cost so far: 429.01
# Iteration 34, best_cost so far: 429.01
# Iteration 35, best_cost so far: 429.01
# Iteration 36, best_cost so far: 429.01
# Iteration 37, best_cost so far: 429.01
# Iteration 38, best_cost so far: 429.01
# Iteration 39, best_cost so far: 331.659
# Iteration 40, best_cost so far: 331.659
# Iteration 41, best_cost so far: 318.068
# Iteration 42, best_cost so far: 318.068
# Iteration 43, best_cost so far: 318.068
# Iteration 44, best_cost so far: 318.068
# Iteration 45, best_cost so far: 318.068
# Iteration 46, best_cost so far: 318.068
# Iteration 47, best_cost so far: 167.157
# Iteration 48, best_cost so far: 167.157
# Iteration 49, best_cost so far: 167.157
# Iteration 50, best_cost so far: 167.157
# Iteration 51, best_cost so far: 130.998
# Iteration 52, best_cost so far: 130.998
# Iteration 53, best_cost so far: 130.998
# Iteration 54, best_cost so far: 130.998
# Iteration 55, best_cost so far: 130.998
# Iteration 56, best_cost so far: 130.998
# Iteration 57, best_cost so far: 130.998
# Iteration 58, best_cost so far: 130.998
# Iteration 59, best_cost so far: 130.998
# Iteration 60, best_cost so far: 130.998
# Iteration 61, best_cost so far: 130.998
# Iteration 62, best_cost so far: 130.998
# Iteration 63, best_cost so far: 130.998
# Iteration 64, best_cost so far: 130.998
# Iteration 65, best_cost so far: 130.998
# Iteration 66, best_cost so far: 130.998
# Iteration 67, best_cost so far: 130.998
# Iteration 68, best_cost so far: 130.998
# Iteration 69, best_cost so far: 130.998
# Iteration 70, best_cost so far: 130.998
# Iteration 71, best_cost so far: 130.998
# Iteration 72, best_cost so far: 130.998
# Iteration 73, best_cost so far: 130.998
# Iteration 74, best_cost so far: 130.998
# Iteration 75, best_cost so far: 130.998
# Iteration 76, best_cost so far: 116.954
# Iteration 77, best_cost so far: 116.954
# Iteration 78, best_cost so far: 116.954
# Iteration 79, best_cost so far: 116.954
# Iteration 80, best_cost so far: 116.954
# Iteration 81, best_cost so far: 95.307
# Iteration 82, best_cost so far: 95.307
# Iteration 83, best_cost so far: 95.307
# Iteration 84, best_cost so far: 95.307
# Iteration 85, best_cost so far: 95.307
# Iteration 86, best_cost so far: 31.17
# Iteration 87, best_cost so far: 31.17
# Iteration 88, best_cost so far: 31.17
# Iteration 89, best_cost so far: 31.17
# Iteration 90, best_cost so far: 31.17
# Iteration 91, best_cost so far: 31.17
# Iteration 92, best_cost so far: 31.17
# Iteration 93, best_cost so far: 31.17
# Iteration 94, best_cost so far: 31.17
# Iteration 95, best_cost so far: 31.17
# Iteration 96, best_cost so far: 31.17
# Iteration 97, best_cost so far: 31.17
# Iteration 98, best_cost so far: 31.17
# Iteration 99, best_cost so far: 31.17
# Iteration 100, best_cost so far: 31.17
# Iteration 101, best_cost so far: 31.17
# Iteration 102, best_cost so far: 31.17
# Iteration 103, best_cost so far: 31.17
# Iteration 104, best_cost so far: 31.17
# Iteration 105, best_cost so far: 31.17
# Iteration 106, best_cost so far: 31.17
# Iteration 107, best_cost so far: 31.17
# Iteration 108, best_cost so far: 31.17
# Iteration 109, best_cost so far: 31.17
# Iteration 110, best_cost so far: 31.17
# Iteration 111, best_cost so far: 31.17
# Iteration 112, best_cost so far: 31.17
# Iteration 113, best_cost so far: 31.17
# Iteration 114, best_cost so far: 31.17
# Iteration 115, best_cost so far: 31.17
# Iteration 116, best_cost so far: 31.17
# Iteration 117, best_cost so far: 31.17
# Iteration 118, best_cost so far: 31.17
# Iteration 119, best_cost so far: 31.17
# Iteration 120, best_cost so far: 31.17
# Iteration 121, best_cost so far: 31.17
# Iteration 122, best_cost so far: 31.17
# Iteration 123, best_cost so far: 31.17
# Iteration 124, best_cost so far: 31.17
# Iteration 125, best_cost so far: 31.17
# Iteration 126, best_cost so far: 31.17
# Iteration 127, best_cost so far: 31.17
# Iteration 128, best_cost so far: 31.17
# Iteration 129, best_cost so far: 31.17
# Iteration 130, best_cost so far: 31.17
# Iteration 131, best_cost so far: 31.17
# Iteration 132, best_cost so far: 31.17
# Iteration 133, best_cost so far: 31.17
# Iteration 134, best_cost so far: 31.17
# Iteration 135, best_cost so far: 31.17
# Iteration 136, best_cost so far: 31.17
# Iteration 137, best_cost so far: 31.17
# Iteration 138, best_cost so far: 31.17
# Iteration 139, best_cost so far: 31.17
# Iteration 140, best_cost so far: 31.17
# Iteration 141, best_cost so far: 31.17
# Iteration 142, best_cost so far: 31.17
# Iteration 143, best_cost so far: 31.17
# Iteration 144, best_cost so far: 31.17
# Iteration 145, best_cost so far: 30.208
# Iteration 146, best_cost so far: 30.208
# Iteration 147, best_cost so far: 30.208
# Iteration 148, best_cost so far: 30.208
# Iteration 149, best_cost so far: 27.791
# Iteration 150, best_cost so far: 27.791
# Iteration 151, best_cost so far: 27.791
# Iteration 152, best_cost so far: 27.791
# Iteration 153, best_cost so far: 27.791
# Iteration 154, best_cost so far: 27.791
# Iteration 155, best_cost so far: 27.791
# Iteration 156, best_cost so far: 27.791
# Iteration 157, best_cost so far: 27.791
# Iteration 158, best_cost so far: 27.791
# Iteration 159, best_cost so far: 24.356
# Iteration 160, best_cost so far: 24.356
# Iteration 161, best_cost so far: 24.356
# Iteration 162, best_cost so far: 24.356
# Iteration 163, best_cost so far: 24.356
# Iteration 164, best_cost so far: 24.356
# Iteration 165, best_cost so far: 24.356
# Iteration 166, best_cost so far: 24.356
# Iteration 167, best_cost so far: 24.356
# Iteration 168, best_cost so far: 24.356
# Iteration 169, best_cost so far: 24.356
# Iteration 170, best_cost so far: 24.356
# Iteration 171, best_cost so far: 24.356
# Iteration 172, best_cost so far: 24.356
# Iteration 173, best_cost so far: 24.356
# Iteration 174, best_cost so far: 24.356
# Iteration 175, best_cost so far: 24.356
# Iteration 176, best_cost so far: 24.356
# Iteration 177, best_cost so far: 24.356
# Iteration 178, best_cost so far: 24.356
# Iteration 179, best_cost so far: 24.356
# Iteration 180, best_cost so far: 24.356
# Iteration 181, best_cost so far: 24.356
# Iteration 182, best_cost so far: 24.356
# Iteration 183, best_cost so far: 24.356
# Iteration 184, best_cost so far: 24.356
# Iteration 185, best_cost so far: 24.356
# Iteration 186, best_cost so far: 24.356
# Iteration 187, best_cost so far: 24.356
# Iteration 188, best_cost so far: 24.356
# Iteration 189, best_cost so far: 24.356
# Iteration 190, best_cost so far: 24.356
# Iteration 191, best_cost so far: 24.356
# Iteration 192, best_cost so far: 24.356
# Iteration 193, best_cost so far: 24.356
# Iteration 194, best_cost so far: 24.356
# Iteration 195, best_cost so far: 24.356
# Iteration 196, best_cost so far: 24.356
# Iteration 197, best_cost so far: 24.356
# Iteration 198, best_cost so far: 24.356
# Iteration 199, best_cost so far: 24.356
# Iteration 200, best_cost so far: 24.356
# Iteration 201, best_cost so far: 24.356
# Iteration 202, best_cost so far: 24.356
# Iteration 203, best_cost so far: 24.356
# Iteration 204, best_cost so far: 24.356
# Iteration 205, best_cost so far: 24.356
# Iteration 206, best_cost so far: 24.356
# Iteration 207, best_cost so far: 24.356
# Iteration 208, best_cost so far: 24.356
# Iteration 209, best_cost so far: 24.356
# Iteration 210, best_cost so far: 24.356
# Iteration 211, best_cost so far: 24.356
# Iteration 212, best_cost so far: 24.356
# Iteration 213, best_cost so far: 24.356
# Iteration 214, best_cost so far: 24.356
# Iteration 215, best_cost so far: 24.356
# Iteration 216, best_cost so far: 24.356
# Iteration 217, best_cost so far: 24.356
# Iteration 218, best_cost so far: 24.356
# Iteration 219, best_cost so far: 24.356
# Iteration 220, best_cost so far: 24.356
# Iteration 221, best_cost so far: 24.356
# Iteration 222, best_cost so far: 24.356
# Iteration 223, best_cost so far: 24.356
# Iteration 224, best_cost so far: 24.356
# Iteration 225, best_cost so far: 24.356
# Iteration 226, best_cost so far: 24.356
# Iteration 227, best_cost so far: 24.356
# Iteration 228, best_cost so far: 24.356
# Iteration 229, best_cost so far: 24.356
# Iteration 230, best_cost so far: 24.356
# Iteration 231, best_cost so far: 24.356
# Iteration 232, best_cost so far: 24.356
# Iteration 233, best_cost so far: 24.356
# Iteration 234, best_cost so far: 24.356
# Iteration 235, best_cost so far: 24.356
# Iteration 236, best_cost so far: 24.356
# Iteration 237, best_cost so far: 24.356
# Iteration 238, best_cost so far: 24.356
# Iteration 239, best_cost so far: 24.356
# Iteration 240, best_cost so far: 24.356
# Iteration 241, best_cost so far: 24.356
# Iteration 242, best_cost so far: 24.356
# Iteration 243, best_cost so far: 24.356
# Iteration 244, best_cost so far: 24.356
# Iteration 245, best_cost so far: 24.356
# Iteration 246, best_cost so far: 24.356
# Iteration 247, best_cost so far: 24.356
# Iteration 248, best_cost so far: 24.356
# Iteration 249, best_cost so far: 24.356
# Iteration 250, best_cost so far: 24.356
# Iteration 251, best_cost so far: 24.356
# Iteration 252, best_cost so far: 24.356
# Iteration 253, best_cost so far: 24.356
# Iteration 254, best_cost so far: 24.356
# Iteration 255, best_cost so far: 24.356
# Iteration 256, best_cost so far: 24.356
# Iteration 257, best_cost so far: 24.356
# Iteration 258, best_cost so far: 24.356
# Iteration 259, best_cost so far: 24.356
# Iteration 260, best_cost so far: 24.356
