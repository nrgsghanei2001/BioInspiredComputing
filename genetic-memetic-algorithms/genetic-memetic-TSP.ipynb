# %%
import random
import math
import numpy as np

# %%
class Data:

    # initialize needed values
    def __init__(self, address):
        self.name = ""
        self.num_cities = 0
        self.locations = []
        self.address = address

    # read test case
    def load_data(self):
        with open (self.address, 'r') as f:
            self.name = f.readline().split(" ")[1]
            self.num_cities = int(self.name[2:])
            f.readline()
            f.readline()
            f.readline()
            f.readline()
            f.readline()
            f.readline()
            for _ in range(self.num_cities):
                city = list(map(float, f.readline().split(" ")))[1:]
                self.locations.append(city)

# %%
class Gene:

    # initialize parameters
    def __init__(self, num_cities, locations):
        self.gene = []
        self.num_cities = num_cities
        self.locations = locations
        self.fitness = math.inf


    # create random gene for first population
    def initial_gene(self):
        self.gene = [i for i in range(self.num_cities)]
        random.shuffle(self.gene)

    # calculate fitness 
    def fitness_function(self):
        self.fitness = 0
        for i in range(self.num_cities-1):
            self.fitness += np.sqrt((self.locations[self.gene[i]][0] - self.locations[self.gene[i+1]][0])**2 + (self.locations[self.gene[i]][1] - self.locations[self.gene[i+1]][1])**2)
        return self.fitness
    
    # mutate gene
    def mutation(self):
        i = random.randint(1, self.num_cities-1)
        j = random.randint(1, self.num_cities-1)

        # randomly replace 2 positions in gene
        tmp = self.gene[i]
        self.gene[i] = self.gene[j]
        self.gene[j] = tmp

        self.fitness = self.fitness_function()

    # define a local search to search for neighbors of a gene that is better than itself
    def local_search(self, num_neighbors):

        neighbors = []
        for _ in range(num_neighbors):
            genei = Gene(self.num_cities, self.locations)
            genei.gene = self.gene
            i = random.randint(1, self.num_cities-1)
            j = random.randint(1, self.num_cities-1)

            # randomly change 2 positions in gene
            tmp = genei.gene[i]
            genei.gene[i] = genei.gene[j]
            genei.gene[j] = tmp
            
            genei.fitness = genei.fitness_function()
            neighbors.append((genei.fitness, genei))

        # select best neighbor
        neighbors.append((self.fitness, self))
        neighbors = sorted(neighbors, key=lambda x: x[0])
        
        return neighbors[0][1]

# %%
class Population:

    # initialize population's parameters
    def __init__(self, data, pop_size=100):
        self.population_size  = pop_size
        self.population       = []
        self.locations        = data.locations
        self.num_cities       = data.num_cities


    # generate first population randomly
    def initialize_population(self):
        for _ in range(self.population_size):
            genei = Gene(self.num_cities, self.locations)
            genei.initial_gene()
            self.population.append(genei)

    # generate first population starting from each city
    def initialize_population_one_city(self):
        for i in range(self.population_size):
            genei         = Gene(self.num_cities, self.locations)
            genei.initial_gene()
            genelist      = genei.gene.copy()
            ind           = genelist.index(i)
            tmp           = genelist[ind]
            genelist[ind] = genelist[0]
            genelist[0]   = tmp
            genei.gene    = genelist
            self.population.append(genei)
    

    # selest parents from population for crossover using tournament selection
    def parent_selection(self, N=3):
        # choose random N candidates to attend tornoment
        father_candidates = [random.choice(self.population) for _ in range(N)]
        mother_candidates = [random.choice(self.population) for _ in range(N)]

        # choose the best one of N candidates to be a parent
        # find candidates fitnesses
        father_vals = [(father.fitness, father) for father in father_candidates]
        mother_vals = [(mother.fitness, mother) for mother in mother_candidates]
        # sort candidates
        sorted_fathers = sorted(father_vals, key=lambda x: x[0])
        sorted_mothers = sorted(mother_vals, key=lambda x: x[0])
        # select parents with min fitness
        best_father = sorted_fathers[0][1]
        best_mother = sorted_mothers[0][1]
        
        return best_father, best_mother


    # crossover function
    def crossover(self, father, mother):
        father = father.gene
        mother = mother.gene
        child1l, child2l = [], []
        child1, child2 = Gene(self.num_cities, self.locations), Gene(self.num_cities, self.locations)
        random_point = random.randint(1, self.num_cities-1)    

        for i in range(0, random_point):
                child1l.append(father[i])
                child2l.append(mother[i])

        for i in range(random_point, self.num_cities):         # add the rest of other parent from random point if its not used before from previous parent
            if mother[i] not in child1l:   
                child1l.append(mother[i])
            
            if father[i] not in child2l:
                child2l.append(father[i])

        for i in range(0, random_point):     # add other parent from first to the random point
            if mother[i] not in child1l:
                child1l.append(mother[i])

            if father[i] not in child2l:
                child2l.append(father[i])
                
        child1.gene    = child1l
        child1.fitness = child1.fitness_function()  
        child2.gene    = child2l 
        child2.fitness = child2.fitness_function() 
        return child1, child2

# %%
def genetic_algorithm_main(test_address, generation_num, p_cross, p_mutate, p_replace, pop_size, tornoment_N, expected_value):
    best_cost = math.inf
    best_result = []
    # load test case
    tsp_test1 = Data(test_address)
    tsp_test1.load_data()

    # create first population
    population = Population(tsp_test1, pop_size=pop_size)
    population.initialize_population()

    for g_num in range(generation_num):
        if best_cost < expected_value:
            break
        # crossover and create as many children as parents population
        children_population = Population(tsp_test1, pop_size=pop_size)
        counter = 0
        while counter < pop_size:
            # select 2 parents for crossover
            father, mother = population.parent_selection(N=tornoment_N)

            # crossover 2 selected parents with p_cross
            e_cross = random.random()
            if e_cross < p_cross:
                child1, child2 = population.crossover(father, mother)
                counter += 2

                # mutate childs with p_mutate
                e_mutate1 = random.random()
                if e_mutate1 < p_mutate:
                    child1.mutation()
                e_mutate2 = random.random()
                if e_mutate2 < p_mutate:
                    child2.mutation()

                children_population.population.append(child1)
                children_population.population.append(child2)
        
        # population replacement
        parent_values = []
        child_values = []
        for i in range(pop_size):             # save all values of parents and children in 2 value lists
            x = population.population[i].fitness
            y = children_population.population[i].fitness
            parent_values.append(x)
            child_values.append(y)

        num_replace = p_replace * pop_size    # find the number of parents that should be replaced with children in population

        for i in range(int(num_replace)):        # replace as the size of replacements in population
            max_parent_ind = parent_values.index(max(parent_values))  # find the worst parent
            min_child_ind = child_values.index(min(child_values))      # find best children

            population.population.pop(max_parent_ind)      # remove worst parent from population
            population.population.append(children_population.population[min_child_ind])  # add best children to population

            children_population.population.pop(min_child_ind)  # remove best children from population of children
            parent_values.pop(max_parent_ind)   # remove worst parent value from parents values
            child_values.pop(min_child_ind)  # remove best children value from children values

        # find the best result in population
        for i in range(pop_size):
            if population.population[i].fitness < best_cost:
                best_cost = population.population[i].fitness
                best_result = population.population[i].gene.copy()

        print(f"generation {g_num}, best_cost so far: {best_cost}")

    return best_result, tsp_test1

# %%
best_result, test = genetic_algorithm_main(test_address="TSP-Tests/gr229.tsp", generation_num=100000, p_cross=0.65, p_mutate=0.6, p_replace=0.1, pop_size=100, tornoment_N=3, expected_value=2500)

# %%
def memetic_algorithm_main(test_address, generation_num, p_cross, p_mutate, p_neighbor, p_replace, pop_size, tornoment_N, expected_value):
    best_cost = math.inf
    best_result = []
    # load test case
    tsp_test1 = Data(test_address)
    tsp_test1.load_data()

    pop_size = tsp_test1.num_cities
    # create first population
    # population = Population(tsp_test1, pop_size=pop_size)
    population = Population(tsp_test1, pop_size=pop_size)
    population.initialize_population_one_city()
    # for i in range(pop_size):
    #     print(population.population[i].gene)
    # population.initialize_population()

    for g_num in range(generation_num):
        if best_cost < expected_value:
            break
        # crossover and create as many children as parents population
        children_population = Population(tsp_test1, pop_size=pop_size)
        # children_population = Population(tsp_test1, pop_size=pop_size)
        counter = 0
        while counter < pop_size:
            # select 2 parents for crossover
            father, mother = population.parent_selection(N=tornoment_N)

            # crossover 2 selected parents with p_cross
            e_cross = random.random()
            if e_cross < p_cross:
                child1, child2 = population.crossover(father, mother)
                counter += 2

                # mutate childs with p_mutate
                e_mutate1 = random.random()
                if e_mutate1 < p_mutate:
                    child1.mutation()
                e_mutate2 = random.random()
                if e_mutate2 < p_mutate:
                    child2.mutation()

                # do local search on chilren's neighbors
                e_neighbor1 = random.random()
                if e_neighbor1 < p_neighbor:
                    genei = child1.local_search(num_neighbors=10)
                else:
                    genei = child1
                e_neighbor2 = random.random()
                if e_neighbor2 < p_neighbor:
                    genej = child2.local_search(num_neighbors=10)
                else:
                    genei = child2

                children_population.population.append(child1)
                children_population.population.append(child2)
        
        # population replacement
        parent_values = []
        child_values = []
        for i in range(pop_size):             # save all values of parents and children in 2 value lists
            x = population.population[i].fitness
            y = children_population.population[i].fitness
            parent_values.append(x)
            child_values.append(y)

        num_replace = p_replace * pop_size    # find the number of parents that should be replaced with children in population

        for i in range(int(num_replace)):        # replace as the size of replacements in population
            max_parent_ind = parent_values.index(max(parent_values))  # find the worst parent
            min_child_ind = child_values.index(min(child_values))      # find best children

            population.population.pop(max_parent_ind)      # remove worst parent from population
            population.population.append(children_population.population[min_child_ind])  # add best children to population

            children_population.population.pop(min_child_ind)  # remove best children from population of children
            parent_values.pop(max_parent_ind)   # remove worst parent value from parents values
            child_values.pop(min_child_ind)  # remove best children value from children values

        # find the best result in population
        for i in range(pop_size):
            if population.population[i].fitness < best_cost:
                best_cost = population.population[i].fitness
                best_result = population.population[i].gene.copy()

        print(f"generation {g_num}, best_cost so far: {best_cost}")

    return best_result, tsp_test1

# %%
best_result, test = memetic_algorithm_main(test_address="TSP-Tests/pr1002.tsp", generation_num=500, p_cross=0.65, p_mutate=0.5, p_neighbor=0.5, p_replace=0.1, pop_size=100, tornoment_N=5, expected_value=2500)
# Out:
# generation 0, best_cost so far: 6138178.101429166
# generation 1, best_cost so far: 6138178.101429166
# generation 2, best_cost so far: 6040086.145148863
# generation 3, best_cost so far: 5989505.858291098
# generation 4, best_cost so far: 5965061.1518393
# generation 5, best_cost so far: 5935108.193463841
# generation 6, best_cost so far: 5897462.322136448
# generation 7, best_cost so far: 5837240.462100838
# generation 8, best_cost so far: 5822009.559247483
# generation 9, best_cost so far: 5790717.5234725345
# generation 10, best_cost so far: 5756722.970047513
# generation 11, best_cost so far: 5742888.750011781
# generation 12, best_cost so far: 5723494.43098761
# generation 13, best_cost so far: 5696791.200616215
# generation 14, best_cost so far: 5667753.252947812
# generation 15, best_cost so far: 5630555.377464153
# generation 16, best_cost so far: 5606092.259768214
# generation 17, best_cost so far: 5583696.443613503
# generation 18, best_cost so far: 5559837.309754811
# generation 19, best_cost so far: 5531567.885869891
# generation 20, best_cost so far: 5531567.885869891
# generation 21, best_cost so far: 5505042.782627583
# generation 22, best_cost so far: 5478896.452142246
# generation 23, best_cost so far: 5443896.440945963
# generation 24, best_cost so far: 5428219.199692173
# generation 25, best_cost so far: 5402689.814354501
# generation 26, best_cost so far: 5397955.076486482
# generation 27, best_cost so far: 5391599.154922304
# generation 28, best_cost so far: 5335624.679790364
# generation 29, best_cost so far: 5335624.679790364
# generation 30, best_cost so far: 5316669.664569747
# generation 31, best_cost so far: 5278352.93156943
# generation 32, best_cost so far: 5278352.93156943
# generation 33, best_cost so far: 5270787.200651613
# generation 34, best_cost so far: 5245593.352007571
# generation 35, best_cost so far: 5198923.199732284
# generation 36, best_cost so far: 5198923.199732284
# generation 37, best_cost so far: 5194860.803668762
# generation 38, best_cost so far: 5181699.319584559
# generation 39, best_cost so far: 5181699.319584559
# generation 40, best_cost so far: 5181005.093123615
# generation 41, best_cost so far: 5165210.413253622
# generation 42, best_cost so far: 5165210.413253622
# generation 43, best_cost so far: 5154829.870529962
# generation 44, best_cost so far: 5120968.312750592
# generation 45, best_cost so far: 5095154.301429989
# generation 46, best_cost so far: 5095154.301429989
# generation 47, best_cost so far: 5093051.112776533
# generation 48, best_cost so far: 5057548.220631716
# generation 49, best_cost so far: 5057548.220631716
# generation 50, best_cost so far: 5037850.5084961215
# generation 51, best_cost so far: 5019507.327031959
# generation 52, best_cost so far: 5006524.805779196
# generation 53, best_cost so far: 4997379.655150488
# generation 54, best_cost so far: 4997379.655150488
# generation 55, best_cost so far: 4997379.655150488
# generation 56, best_cost so far: 4996924.950854615
# generation 57, best_cost so far: 4981939.815459585
# generation 58, best_cost so far: 4969428.139981111
# generation 59, best_cost so far: 4965778.00859013
# generation 60, best_cost so far: 4962129.849719645
# generation 61, best_cost so far: 4962129.849719645
# generation 62, best_cost so far: 4957368.135820678
# generation 63, best_cost so far: 4934812.505897109
# generation 64, best_cost so far: 4934812.505897109
# generation 65, best_cost so far: 4934812.505897109
# generation 66, best_cost so far: 4901487.258919359
# generation 67, best_cost so far: 4901487.258919359
# generation 68, best_cost so far: 4893938.449967073
# generation 69, best_cost so far: 4877989.911337092
# generation 70, best_cost so far: 4877989.911337092
# generation 71, best_cost so far: 4873685.66440476
# generation 72, best_cost so far: 4873685.66440476
# generation 73, best_cost so far: 4869884.618410888
# generation 74, best_cost so far: 4852980.187149686
# generation 75, best_cost so far: 4842073.937574379
# generation 76, best_cost so far: 4823745.081259124
# generation 77, best_cost so far: 4803100.060599001
# generation 78, best_cost so far: 4803100.060599001
# generation 79, best_cost so far: 4803100.060599001
# generation 80, best_cost so far: 4803100.060599001
# generation 81, best_cost so far: 4801854.208219649
# generation 82, best_cost so far: 4795747.323984927
# generation 83, best_cost so far: 4795747.323984927
# generation 84, best_cost so far: 4788667.6329868
# generation 85, best_cost so far: 4775575.112297682
# generation 86, best_cost so far: 4775575.112297682
# generation 87, best_cost so far: 4764021.56502649
# generation 88, best_cost so far: 4757618.494761217
# generation 89, best_cost so far: 4756974.077297831
# generation 90, best_cost so far: 4742243.2340428475
# generation 91, best_cost so far: 4736424.60269654
# generation 92, best_cost so far: 4724285.885120601
# generation 93, best_cost so far: 4724285.885120601
# generation 94, best_cost so far: 4724285.885120601
# generation 95, best_cost so far: 4721493.46534028
# generation 96, best_cost so far: 4705029.137681198
# generation 97, best_cost so far: 4705029.137681198
# generation 98, best_cost so far: 4697226.437794956
# generation 99, best_cost so far: 4678663.121914714
# generation 100, best_cost so far: 4678663.121914714
# generation 101, best_cost so far: 4674637.907101953
# generation 102, best_cost so far: 4661384.885113857
# generation 103, best_cost so far: 4658288.434842017
# generation 104, best_cost so far: 4658288.434842017
# generation 105, best_cost so far: 4649064.110381472
# generation 106, best_cost so far: 4640071.94237796
# generation 107, best_cost so far: 4640071.94237796
# generation 108, best_cost so far: 4640071.94237796
# generation 109, best_cost so far: 4624356.032960287
# generation 110, best_cost so far: 4624356.032960287
# generation 111, best_cost so far: 4623310.7427362595
# generation 112, best_cost so far: 4619287.060461033
# generation 113, best_cost so far: 4611272.320394551
# generation 114, best_cost so far: 4611272.320394551
# generation 115, best_cost so far: 4602710.117724882
# generation 116, best_cost so far: 4602710.117724882
# generation 117, best_cost so far: 4583283.213728353
# generation 118, best_cost so far: 4583283.213728353
# generation 119, best_cost so far: 4575571.876802491
# generation 120, best_cost so far: 4575571.876802491
# generation 121, best_cost so far: 4575571.876802491
# generation 122, best_cost so far: 4556672.485071389
# generation 123, best_cost so far: 4556672.485071389
# generation 124, best_cost so far: 4556672.485071389
# generation 125, best_cost so far: 4554176.675469246
# generation 126, best_cost so far: 4554176.675469246
# generation 127, best_cost so far: 4551245.337202695
# generation 128, best_cost so far: 4547196.753728
# generation 129, best_cost so far: 4531266.096168792
# generation 130, best_cost so far: 4522925.644975599
# generation 131, best_cost so far: 4518996.236382553
# generation 132, best_cost so far: 4518996.236382553
# generation 133, best_cost so far: 4512576.686358123
# generation 134, best_cost so far: 4503122.801432269
# generation 135, best_cost so far: 4496113.43553783
# generation 136, best_cost so far: 4486614.5741815
# generation 137, best_cost so far: 4484003.955388157
# generation 138, best_cost so far: 4484003.955388157
# generation 139, best_cost so far: 4482640.848622374
# generation 140, best_cost so far: 4464619.746085712
# generation 141, best_cost so far: 4464619.746085712
# generation 142, best_cost so far: 4461203.742466909
# generation 143, best_cost so far: 4461203.742466909
# generation 144, best_cost so far: 4460189.960023603
# generation 145, best_cost so far: 4456498.144105298
# generation 146, best_cost so far: 4447655.758718778
# generation 147, best_cost so far: 4440317.525214551
# generation 148, best_cost so far: 4425992.868883997
# generation 149, best_cost so far: 4425992.868883997
# generation 150, best_cost so far: 4425992.868883997
# generation 151, best_cost so far: 4425992.868883997
# generation 152, best_cost so far: 4425992.868883997
# generation 153, best_cost so far: 4425992.868883997
# generation 154, best_cost so far: 4425992.868883997
# generation 155, best_cost so far: 4425992.868883997
# generation 156, best_cost so far: 4422209.3341943445
# generation 157, best_cost so far: 4422209.3341943445
# generation 158, best_cost so far: 4413403.070576655
# generation 159, best_cost so far: 4413403.070576655
# generation 160, best_cost so far: 4406762.035431827
# generation 161, best_cost so far: 4406762.035431827
# generation 162, best_cost so far: 4406762.035431827
# generation 163, best_cost so far: 4406762.035431827
# generation 164, best_cost so far: 4398084.704877839
# generation 165, best_cost so far: 4384163.277139561
# generation 166, best_cost so far: 4384163.277139561
# generation 167, best_cost so far: 4377934.898335961
# generation 168, best_cost so far: 4367686.62991596
# generation 169, best_cost so far: 4367686.62991596
# generation 170, best_cost so far: 4367686.62991596
# generation 171, best_cost so far: 4367686.62991596
# generation 172, best_cost so far: 4367686.62991596
# generation 173, best_cost so far: 4367686.62991596
# generation 174, best_cost so far: 4358403.8304187665
# generation 175, best_cost so far: 4358403.8304187665
# generation 176, best_cost so far: 4358403.8304187665
# generation 177, best_cost so far: 4355000.288647563
# generation 178, best_cost so far: 4343235.364390373
# generation 179, best_cost so far: 4342550.628258178
# generation 180, best_cost so far: 4342550.628258178
# generation 181, best_cost so far: 4336844.563146839
# generation 182, best_cost so far: 4334280.137522177
# generation 183, best_cost so far: 4329438.5765058985
# generation 184, best_cost so far: 4326059.907450239
# generation 185, best_cost so far: 4325401.5428963965
# generation 186, best_cost so far: 4313668.468626771
# generation 187, best_cost so far: 4313668.468626771
# generation 188, best_cost so far: 4307298.993446194
# generation 189, best_cost so far: 4303312.663654898
# generation 190, best_cost so far: 4303312.663654898
# generation 191, best_cost so far: 4297515.800762746
# generation 192, best_cost so far: 4289207.361356887
# generation 193, best_cost so far: 4277548.069052388
# generation 194, best_cost so far: 4277548.069052388
# generation 195, best_cost so far: 4275115.20077565
# generation 196, best_cost so far: 4275115.20077565
# generation 197, best_cost so far: 4271968.30381099
# generation 198, best_cost so far: 4271968.30381099
# generation 199, best_cost so far: 4267563.451528836
# generation 200, best_cost so far: 4267497.47516322
# generation 201, best_cost so far: 4263520.049924176
# generation 202, best_cost so far: 4258568.214690628
# generation 203, best_cost so far: 4258167.306123129
# generation 204, best_cost so far: 4242306.122730176
# generation 205, best_cost so far: 4242306.122730176
# generation 206, best_cost so far: 4241553.222534047
# generation 207, best_cost so far: 4235890.170880603
# generation 208, best_cost so far: 4234419.642459508
# generation 209, best_cost so far: 4229370.082536546
# generation 210, best_cost so far: 4229370.082536546
# generation 211, best_cost so far: 4229370.082536546
# generation 212, best_cost so far: 4218347.767779094
# generation 213, best_cost so far: 4218347.767779094
# generation 214, best_cost so far: 4216403.872254032
# generation 215, best_cost so far: 4211572.38984987
# generation 216, best_cost so far: 4207889.262244726
# generation 217, best_cost so far: 4207230.093013334
# generation 218, best_cost so far: 4198729.18527089
# generation 219, best_cost so far: 4198729.18527089
# generation 220, best_cost so far: 4195986.736662791
# generation 221, best_cost so far: 4187987.822308722
# generation 222, best_cost so far: 4178479.673059959
# generation 223, best_cost so far: 4169150.095719478
# generation 224, best_cost so far: 4169150.095719478
# generation 225, best_cost so far: 4167066.936326124
# generation 226, best_cost so far: 4167066.936326124
# generation 227, best_cost so far: 4167066.936326124
# generation 228, best_cost so far: 4162521.318746052
# generation 229, best_cost so far: 4162521.318746052
# generation 230, best_cost so far: 4162521.318746052
# generation 231, best_cost so far: 4156057.0890495377
# generation 232, best_cost so far: 4156057.0890495377
# generation 233, best_cost so far: 4151347.9753564377
# generation 234, best_cost so far: 4151347.9753564377
# generation 235, best_cost so far: 4151347.9753564377
# generation 236, best_cost so far: 4144762.6213233736
# generation 237, best_cost so far: 4144762.6213233736
# generation 238, best_cost so far: 4144762.6213233736
# generation 239, best_cost so far: 4144762.6213233736
# generation 240, best_cost so far: 4137572.4295969442
# generation 241, best_cost so far: 4137572.4295969442
# generation 242, best_cost so far: 4131024.951653794
# generation 243, best_cost so far: 4123091.556076805
# generation 244, best_cost so far: 4123091.556076805
# generation 245, best_cost so far: 4119904.4127831925
# generation 246, best_cost so far: 4116925.700688487
# generation 247, best_cost so far: 4116925.700688487
# generation 248, best_cost so far: 4110345.340491677
# generation 249, best_cost so far: 4110275.425551083
# generation 250, best_cost so far: 4103756.1639161548
# generation 251, best_cost so far: 4100785.277808252
# generation 252, best_cost so far: 4100785.277808252
# generation 253, best_cost so far: 4100785.277808252
# generation 254, best_cost so far: 4090249.8381148996
# generation 255, best_cost so far: 4090249.8381148996
# generation 256, best_cost so far: 4084722.6411586874
# generation 257, best_cost so far: 4084722.6411586874
# generation 258, best_cost so far: 4084722.6411586874
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14560\1046964067.py in <module>
# ----> 1 best_result, test = memetic_algorithm_main(test_address="TSP-Tests/pr1002.tsp", generation_num=500, p_cross=0.65, p_mutate=0.5, p_neighbor=0.5, p_replace=0.1, pop_size=100, tornoment_N=5, expected_value=2500)
#
# ~\AppData\Local\Temp\ipykernel_14560\2148432549.py in memetic_algorithm_main(test_address, generation_num, p_cross, p_mutate, p_neighbor, p_replace, pop_size, tornoment_N, expected_value)
#      29             e_cross = random.random()
#      30             if e_cross < p_cross:
# ---> 31                 child1, child2 = population.crossover(father, mother)
#      32                 counter += 2
#      33
#
# ~\AppData\Local\Temp\ipykernel_14560\2960391371.py in crossover(self, father, mother)
#      70
#      71         for i in range(0, random_point):     # add mother from first to the random point
# ---> 72             if mother[i] not in child1l:
#      73                 child1l.append(mother[i])
#      74
#
# KeyboardInterrupt:
